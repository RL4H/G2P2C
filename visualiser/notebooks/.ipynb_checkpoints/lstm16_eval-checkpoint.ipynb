# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='mygpu_m28_lstm16_0', version=1.1)
exp2 = ExperimentVisualise(id='mygpu_m28_lstm16_1', version=1.1)
exp3 = ExperimentVisualise(id='mygpu_m28_lstm16_2', version=1.1)
exp4 = ExperimentVisualise(id='mygpu_m28_lstm16_5', version=1.1)

# False
# exp4

exp_vis = {'1':{
                "id":exp1,
                "color":'r',
                "show": True},
           '2':{
                "id":exp2,
                "color":'g',
                "show": True},
           '3':{
                "id":exp3,
                "color":'b',
                "show": True},
           '4':{
                "id":exp4,
                "color":'m',
                "show": True}
           }

# plot the graphs
dis_len = 5000000
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_training_logs(exp_vis, dis_len)
plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp3
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 2000
plot_episode(target_exp, tester=0, episode=target_epi)
plot_episode(target_exp, tester=1, episode=target_epi)
plot_episode(target_exp, tester=2, episode=target_epi)
plot_episode(target_exp, tester=3, episode=target_epi)
plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {3650: 7302}, 't': {3650: 71}, 'reward': {3650: 59.32075}, 'normo': {3650: 28.169014084507044}, 'hypo': {3650: 15.492957746478874}, 'sev_hypo': {3650: 11.267605633802816}, 'hyper': {3650: 56.33802816901409}, 'lgbi': {3650: 15.7836075}, 'hgbi': {3650: 14.251826}, 'ri': {3650: 30.035435}}
# {'epi': {3650: 7302}, 't': {3650: 42}, 'reward': {3650: 30.027628}, 'normo': {3650: 21.428571428571427}, 'hypo': {3650: 11.904761904761903}, 'sev_hypo': {3650: 7.142857142857143}, 'hyper': {3650: 66.66666666666667}, 'lgbi': {3650: 14.641807}, 'hgbi': {3650: 30.41403}, 'ri': {3650: 45.055836}}
# {'epi': {3650: 7302}, 't': {3650: 40}, 'reward': {3650: 36.816044}, 'normo': {3650: 72.5}, 'hypo': {3650: 10.0}, 'sev_hypo': {3650: 7.5}, 'hyper': {3650: 17.5}, 'lgbi': {3650: 10.935419}, 'hgbi': {3650: 4.7002807}, 'ri': {3650: 15.6357}}
# {'epi': {3650: 7302}, 't': {3650: 288}, 'reward': {3650: 260.99872}, 'normo': {3650: 63.888888888888886}, 'hypo': {3650: 11.11111111111111}, 'sev_hypo': {3650: 1.3888888888888888}, 'hyper': {3650: 25.0}, 'lgbi': {3650: 9.17632}, 'hgbi': {3650: 9.435805}, 'ri': {3650: 18.612125}}
# {'epi': {3650: 7302}, 't': {3650: 93}, 'reward': {3650: 83.30676}, 'normo': {3650: 68.81720430107526}, 'hypo': {3650: 7.526881720430108}, 'sev_hypo': {3650: 4.301075268817204}, 'hyper': {3650: 23.655913978494624}, 'lgbi': {3650: 13.869529}, 'hgbi': {3650: 8.2245035}, 'ri': {3650: 22.094032}}
