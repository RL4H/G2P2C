# %%
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
import pandas as pd
import numpy as np
import json
   
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j28_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='j28_1', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='j28_2', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='j28_3', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='j28_4', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='j28_5', version=1.1, plot_version=1)
# exp7 = ExperimentVisualise(id='j25_6', version=1.1, plot_version=1)
# exp8 = ExperimentVisualise(id='j25_7', version=1.1, plot_version=1)
# exp9 = ExperimentVisualise(id='j25_8', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='j25_9', version=1.1, plot_version=1)

command = []
dis_len = 6000000
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
#            '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
#            '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
#            '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#            '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)

# %%
# debugging a given experimentset_args
target_exp = exp2
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=5000)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {745: 1492}, 't': {745: 139}, 'reward': {745: 131.91022}, 'normo': {745: 84.89208633093526}, 'hypo': {745: 2.158273381294964}, 'sev_hypo': {745: 2.158273381294964}, 'hyper': {745: 10.79136690647482}, 'lgbi': {745: 4.21052}, 'hgbi': {745: 3.363656}, 'ri': {745: 7.574176}, 'sev_hyper': {745: 0.0}}
# {'epi': {745: 1492}, 't': {745: 312}, 'reward': {745: 247.61885}, 'normo': {745: 35.8974358974359}, 'hypo': {745: 13.461538461538462}, 'sev_hypo': {745: 5.769230769230769}, 'hyper': {745: 38.782051282051285}, 'lgbi': {745: 10.121032}, 'hgbi': {745: 15.008437}, 'ri': {745: 25.129469}, 'sev_hyper': {745: 6.089743589743589}}
# {'epi': {745: 1492}, 't': {745: 53}, 'reward': {745: 38.261806}, 'normo': {745: 35.84905660377358}, 'hypo': {745: 13.20754716981132}, 'sev_hypo': {745: 3.7735849056603774}, 'hyper': {745: 32.075471698113205}, 'lgbi': {745: 9.834154}, 'hgbi': {745: 18.243208}, 'ri': {745: 28.077362}, 'sev_hyper': {745: 15.09433962264151}}
# {'epi': {745: 1492}, 't': {745: 119}, 'reward': {745: 93.58853}, 'normo': {745: 55.46218487394958}, 'hypo': {745: 6.722689075630252}, 'sev_hypo': {745: 2.5210084033613445}, 'hyper': {745: 22.689075630252105}, 'lgbi': {745: 6.5410495}, 'hgbi': {745: 16.027586}, 'ri': {745: 22.568636}, 'sev_hyper': {745: 12.605042016806722}}
# {'epi': {745: 1492}, 't': {745: 11}, 'reward': {745: 2.468737}, 'normo': {745: 0.0}, 'hypo': {745: 0.0}, 'sev_hypo': {745: 0.0}, 'hyper': {745: 27.272727272727277}, 'lgbi': {745: 0.0}, 'hgbi': {745: 57.13344}, 'ri': {745: 57.13344}, 'sev_hyper': {745: 72.72727272727273}}
