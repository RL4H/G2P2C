# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue = '#483D8B'

exp1 = ExperimentVisualise(id='oct7_2_ppo_normal_clip01', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='oct7_2_ppo_quadratic_clip01', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='oct7_2_ppo_propquad_clip01', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='oct7_2_ppo_quadratic_clip005', version=1.1, plot_version=1, test_seeds=5000)
exp5 = ExperimentVisualise(id='oct7_2_ppo_exponential_clip01', version=1.1, plot_version=1, test_seeds=5000)
exp6 = ExperimentVisualise(id='oct7_2_ppo_exponential_clip01_128workers', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='oct7_2_ppo_proportional_quadratic_clip01_128workers', version=1.1, plot_version=1, test_seeds=5000)


# plot the graphs
dis_len = 5 * 1000000
command = ['off 1 2 3 4']
disp_arr = display_commands_v2(command)
exp_vis = {
           '1':{ "id":exp1, "color":'k',"show": disp_arr[1]}, 
           '2':{ "id":exp2, "color":'r',"show": disp_arr[2]},  
           '3':{ "id":exp3, "color":'b', "show": disp_arr[3]},
           '4':{ "id":exp4, "color":'g', "show": disp_arr[4]},
           '5':{ "id":exp5, "color":'m', "show": disp_arr[5]},
           '6':{ "id":exp6, "color":darkslateblue, "show": disp_arr[6]},
           '7':{ "id":exp7, "color":brown, "show": disp_arr[7]},
          }

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=True)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
#plot_aux_training(exp_vis, 300, 10)

# %%
#debugging a given experimentset_args
target_exp = exp5
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {158: 160}, 't': {158: 135}, 'reward': {158: 108.0441}, 'normo': {158: 28.88888888888889}, 'hypo': {158: 0.7407407407407407}, 'sev_hypo': {158: 1.4814814814814814}, 'hyper': {158: 51.11111111111112}, 'lgbi': {158: 17.689508}, 'hgbi': {158: 19.579561}, 'ri': {158: 37.26907}, 'sev_hyper': {158: 17.77777777777778}}
# {'epi': {158: 160}, 't': {158: 312}, 'reward': {158: 215.75389}, 'normo': {158: 28.846153846153847}, 'hypo': {158: 0.0}, 'sev_hypo': {158: 0.0}, 'hyper': {158: 23.71794871794872}, 'lgbi': {158: 0.0}, 'hgbi': {158: 30.848106}, 'ri': {158: 30.848106}, 'sev_hyper': {158: 47.43589743589744}}
# {'epi': {158: 160}, 't': {158: 312}, 'reward': {158: 256.6479}, 'normo': {158: 35.256410256410255}, 'hypo': {158: 0.0}, 'sev_hypo': {158: 0.0}, 'hyper': {158: 54.16666666666666}, 'lgbi': {158: 0.013698934}, 'hgbi': {158: 17.798061}, 'ri': {158: 17.81176}, 'sev_hyper': {158: 10.576923076923077}}
# {'epi': {158: 160}, 't': {158: 312}, 'reward': {158: 246.10675}, 'normo': {158: 39.74358974358975}, 'hypo': {158: 0.0}, 'sev_hypo': {158: 0.0}, 'hyper': {158: 31.73076923076923}, 'lgbi': {158: 0.96694916}, 'hgbi': {158: 24.693874}, 'ri': {158: 25.660824}, 'sev_hyper': {158: 28.525641025641026}}
# {'epi': {158: 160}, 't': {158: 312}, 'reward': {158: 234.62445}, 'normo': {158: 34.93589743589744}, 'hypo': {158: 0.0}, 'sev_hypo': {158: 0.0}, 'hyper': {158: 37.5}, 'lgbi': {158: 0.39452922}, 'hgbi': {158: 26.471443}, 'ri': {158: 26.865973}, 'sev_hyper': {158: 27.56410256410257}}
# {'epi': {158: 160}, 't': {158: 312}, 'reward': {158: 217.35587}, 'normo': {158: 29.807692307692307}, 'hypo': {158: 0.0}, 'sev_hypo': {158: 0.0}, 'hyper': {158: 24.03846153846154}, 'lgbi': {158: 0.07210045}, 'hgbi': {158: 31.65042}, 'ri': {158: 31.722519}, 'sev_hyper': {158: 46.15384615384615}}
# {'epi': {158: 160}, 't': {158: 206}, 'reward': {158: 161.38116}, 'normo': {158: 25.728155339805824}, 'hypo': {158: 2.4271844660194173}, 'sev_hypo': {158: 1.941747572815534}, 'hyper': {158: 52.42718446601942}, 'lgbi': {158: 16.40503}, 'hgbi': {158: 21.68956}, 'ri': {158: 38.09459}, 'sev_hyper': {158: 17.475728155339805}}
# {'epi': {158: 160}, 't': {158: 130}, 'reward': {158: 100.037125}, 'normo': {158: 26.923076923076923}, 'hypo': {158: 0.7692307692307693}, 'sev_hypo': {158: 1.5384615384615383}, 'hyper': {158: 63.07692307692308}, 'lgbi': {158: 20.5778}, 'hgbi': {158: 22.652803}, 'ri': {158: 43.230606}, 'sev_hyper': {158: 7.6923076923076925}}
# {'epi': {158: 160}, 't': {158: 312}, 'reward': {158: 219.77686}, 'normo': {158: 17.307692307692307}, 'hypo': {158: 0.0}, 'sev_hypo': {158: 0.0}, 'hyper': {158: 47.756410256410255}, 'lgbi': {158: 0.0}, 'hgbi': {158: 29.558695}, 'ri': {158: 29.558695}, 'sev_hyper': {158: 34.93589743589744}}
# {'epi': {158: 160}, 't': {158: 312}, 'reward': {158: 232.5216}, 'normo': {158: 8.974358974358974}, 'hypo': {158: 0.0}, 'sev_hypo': {158: 0.0}, 'hyper': {158: 67.3076923076923}, 'lgbi': {158: 0.0}, 'hgbi': {158: 25.473837}, 'ri': {158: 25.473837}, 'sev_hyper': {158: 23.71794871794872}}

# %%
from utils.reward_func_explore import plot_reward
plot_reward(rew_func=['original'], color=['r', 'g', 'b'], guidelines=False)
plot_reward(rew_func=['original','severe_aggressive', 'smooth_aggressive'], color=['r', 'g', 'b'], guidelines=False)
