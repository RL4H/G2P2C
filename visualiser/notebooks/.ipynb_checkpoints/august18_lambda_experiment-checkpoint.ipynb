# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='aug18_0_5', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='aug18_0_6', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='aug18_0_7', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='aug18_0_8', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='aug18_0_95', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='aug18_0_99', version=1.1, plot_version=1)

command = []
dis_len = 3000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
            '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
             '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
              '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 10)

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 300.25772}, 'normo': {266: 85.25641025641026}, 'hypo': {266: 0.6410256410256411}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 14.102564102564102}, 'lgbi': {266: 2.3149736}, 'hgbi': {266: 4.3693123}, 'ri': {266: 6.684286}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 304.76437}, 'normo': {266: 94.55128205128206}, 'hypo': {266: 0.0}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 5.448717948717949}, 'lgbi': {266: 1.7065234}, 'hgbi': {266: 2.9722695}, 'ri': {266: 4.678793}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 301.96002}, 'normo': {266: 82.37179487179488}, 'hypo': {266: 1.2820512820512822}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 16.346153846153847}, 'lgbi': {266: 1.8609395}, 'hgbi': {266: 4.1371946}, 'ri': {266: 5.998134}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 301.7021}, 'normo': {266: 89.42307692307692}, 'hypo': {266: 3.525641025641025}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 7.051282051282051}, 'lgbi': {266: 3.2591763}, 'hgbi': {266: 3.3158858}, 'ri': {266: 6.575062}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 303.17233}, 'normo': {266: 88.46153846153847}, 'hypo': {266: 0.0}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 11.538461538461538}, 'lgbi': {266: 0.5984411}, 'hgbi': {266: 3.4746966}, 'ri': {266: 4.0731378}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 305.23758}, 'normo': {266: 99.35897435897436}, 'hypo': {266: 0.6410256410256411}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 0.0}, 'lgbi': {266: 1.5621812}, 'hgbi': {266: 2.4878726}, 'ri': {266: 4.0500536}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 303.78427}, 'normo': {266: 91.02564102564102}, 'hypo': {266: 0.0}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 8.974358974358974}, 'lgbi': {266: 2.2214332}, 'hgbi': {266: 2.880339}, 'ri': {266: 5.1017723}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 295.97864}, 'normo': {266: 70.51282051282051}, 'hypo': {266: 6.410256410256411}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 23.07692307692308}, 'lgbi': {266: 5.377345}, 'hgbi': {266: 5.047231}, 'ri': {266: 10.424576}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 297.4906}, 'normo': {266: 77.88461538461539}, 'hypo': {266: 7.051282051282051}, 'sev_hypo': {266: 0.3205128205128205}, 'hyper': {266: 14.743589743589745}, 'lgbi': {266: 5.607798}, 'hgbi': {266: 4.2623377}, 'ri': {266: 9.870136}, 'sev_hyper': {266: 0.0}}
# {'epi': {266: 268}, 't': {266: 312}, 'reward': {266: 298.87872}, 'normo': {266: 80.44871794871794}, 'hypo': {266: 0.0}, 'sev_hypo': {266: 0.0}, 'hyper': {266: 19.55128205128205}, 'lgbi': {266: 0.9878708}, 'hgbi': {266: 5.571935}, 'ri': {266: 6.559806}, 'sev_hyper': {266: 0.0}}
