# %%
import os
import sys
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
import pandas as pd
import numpy as np
import json
    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='jul1_2_lstm32', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='jul1_4_lstm32', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='jul1_2_lstm16_2', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='jul1_2_lstm16_4', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='jul1_2_entropy_0', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='jul1_4_entropy_0', version=1.1, plot_version=1)
exp7 = ExperimentVisualise(id='jul1_2_clip', version=1.1, plot_version=1)
exp8 = ExperimentVisualise(id='jul1_4_clip', version=1.1, plot_version=1)
# exp9 = ExperimentVisualise(id='j25_8', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='j25_9', version=1.1, plot_version=1)

command = []
dis_len = 7000000
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
            '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
            '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
#            '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#            '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=288)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {350: 702}, 't': {350: 312}, 'reward': {350: 251.64896}, 'normo': {350: 55.44871794871795}, 'hypo': {350: 1.9230769230769231}, 'sev_hypo': {350: 1.9230769230769231}, 'hyper': {350: 31.08974358974359}, 'lgbi': {350: 4.2267556}, 'hgbi': {350: 14.718554}, 'ri': {350: 18.945309}, 'sev_hyper': {350: 9.615384615384617}}
# {'epi': {350: 702}, 't': {350: 312}, 'reward': {350: 297.6431}, 'normo': {350: 79.8076923076923}, 'hypo': {350: 2.243589743589744}, 'sev_hypo': {350: 0.0}, 'hyper': {350: 17.94871794871795}, 'lgbi': {350: 2.1139784}, 'hgbi': {350: 5.473842}, 'ri': {350: 7.5878205}, 'sev_hyper': {350: 0.0}}
# {'epi': {350: 702}, 't': {350: 312}, 'reward': {350: 231.22466}, 'normo': {350: 58.97435897435897}, 'hypo': {350: 0.0}, 'sev_hypo': {350: 0.0}, 'hyper': {350: 19.55128205128205}, 'lgbi': {350: 0.75913423}, 'hgbi': {350: 17.824896}, 'ri': {350: 18.58403}, 'sev_hyper': {350: 21.47435897435897}}
# {'epi': {350: 702}, 't': {350: 192}, 'reward': {350: 165.78612}, 'normo': {350: 63.020833333333336}, 'hypo': {350: 5.208333333333333}, 'sev_hypo': {350: 2.6041666666666665}, 'hyper': {350: 25.0}, 'lgbi': {350: 10.206146}, 'hgbi': {350: 8.947973}, 'ri': {350: 19.15412}, 'sev_hyper': {350: 4.166666666666667}}
# {'epi': {350: 702}, 't': {350: 312}, 'reward': {350: 284.9269}, 'normo': {350: 72.75641025641026}, 'hypo': {350: 0.0}, 'sev_hypo': {350: 0.0}, 'hyper': {350: 25.32051282051282}, 'lgbi': {350: 0.9823062}, 'hgbi': {350: 8.181721}, 'ri': {350: 9.164027}, 'sev_hyper': {350: 1.9230769230769231}}
