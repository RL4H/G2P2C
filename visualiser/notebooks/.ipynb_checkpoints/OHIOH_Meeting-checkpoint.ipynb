# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
ppo_aux_lstm16 = ExperimentVisualise(id='ppo_aux_lstm16')
lstm16_288_pi_low= ExperimentVisualise(id='lstm16_288_pi_low')

exp_vis = {
           '4':{
                "id":ppo_aux_lstm16,
                "color":'m',
                "show": True},
           '5':{
                "id":lstm16_288_pi_low,
                "color":'g',
                "show": True} 
           }

# plot the graphs
dis_len = 1000000
plot_testing_rewards(exp_vis, 'min_max',dis_len)  # min_max, normal
plot_training_logs(exp_vis, dis_len)

# %%
# debugging a given experiment
target_exp = ppo_aux_lstm16
target_exp.get_summary()
plot_episode(target_exp, tester=4, episode=286)
plot_value_function(target_exp, horizon=100)
plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {286: 287}, 't': {286: 288}, 'reward': {286: 273.8102}, 'normo': {286: 81.59722222222223}, 'hypo': {286: 5.208333333333333}, 'sev_hypo': {286: 0.0}, 'hyper': {286: 13.194444444444445}, 'lgbi': {286: 4.9906945}, 'hgbi': {286: 4.901216}, 'ri': {286: 9.891911}}
# {'epi': {286: 287}, 't': {286: 288}, 'reward': {286: 279.06378}, 'normo': {286: 88.54166666666667}, 'hypo': {286: 0.0}, 'sev_hypo': {286: 0.0}, 'hyper': {286: 11.458333333333334}, 'lgbi': {286: 0.79394454}, 'hgbi': {286: 4.2393494}, 'ri': {286: 5.0332937}}
# {'epi': {286: 287}, 't': {286: 288}, 'reward': {286: 278.1136}, 'normo': {286: 85.41666666666667}, 'hypo': {286: 0.0}, 'sev_hypo': {286: 0.0}, 'hyper': {286: 14.583333333333334}, 'lgbi': {286: 0.7170148}, 'hgbi': {286: 4.0171833}, 'ri': {286: 4.734198}}
# {'epi': {285: 286}, 't': {285: 288}, 'reward': {285: 277.70517}, 'normo': {285: 84.375}, 'hypo': {285: 0.0}, 'sev_hypo': {285: 0.0}, 'hyper': {285: 15.625}, 'lgbi': {285: 0.863469}, 'hgbi': {285: 4.74807}, 'ri': {285: 5.611539}}
# {'epi': {285: 286}, 't': {285: 288}, 'reward': {285: 283.05316}, 'normo': {285: 100.0}, 'hypo': {285: 0.0}, 'sev_hypo': {285: 0.0}, 'hyper': {285: 0.0}, 'lgbi': {285: 1.0323982}, 'hgbi': {285: 2.483526}, 'ri': {285: 3.5159242}}
