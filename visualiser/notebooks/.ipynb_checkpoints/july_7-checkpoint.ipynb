# %%
import os
import sys
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
import pandas as pd
import numpy as np
import json
    
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='july7_3_new_meal', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='july7_3_t_meal_30', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='july7_0_newmeal', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='july7_2_newmeal', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='july7_3_lowhorizon', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='july7_3_mediumhorizon', version=1.1, plot_version=1)
# exp7 = ExperimentVisualise(id='july2_0', version=1.1, plot_version=1)
# exp8 = ExperimentVisualise(id='july2_0', version=1.1, plot_version=1)
# exp9 = ExperimentVisualise(id='j25_8', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='j25_9', version=1.1, plot_version=1)

command = []
dis_len = 5000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
#            '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
#            '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
#            '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#            '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)

# %%
# debugging a given experimentset_args
target_exp = exp3
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {83: 168}, 't': {83: 134}, 'reward': {83: 88.24437}, 'normo': {83: 34.32835820895522}, 'hypo': {83: 5.223880597014926}, 'sev_hypo': {83: 5.223880597014926}, 'hyper': {83: 35.07462686567164}, 'lgbi': {83: 10.905688}, 'hgbi': {83: 23.126873}, 'ri': {83: 34.032562}, 'sev_hyper': {83: 20.149253731343283}}
# {'epi': {83: 168}, 't': {83: 312}, 'reward': {83: 278.88794}, 'normo': {83: 54.80769230769231}, 'hypo': {83: 24.03846153846154}, 'sev_hypo': {83: 0.0}, 'hyper': {83: 18.58974358974359}, 'lgbi': {83: 7.665868}, 'hgbi': {83: 10.591071}, 'ri': {83: 18.256939}, 'sev_hyper': {83: 2.5641025641025643}}
# {'epi': {83: 168}, 't': {83: 153}, 'reward': {83: 129.83777}, 'normo': {83: 40.52287581699346}, 'hypo': {83: 11.11111111111111}, 'sev_hypo': {83: 2.6143790849673203}, 'hyper': {83: 44.44444444444444}, 'lgbi': {83: 9.885767}, 'hgbi': {83: 13.3821745}, 'ri': {83: 23.26794}, 'sev_hyper': {83: 1.30718954248366}}
# {'epi': {83: 168}, 't': {83: 248}, 'reward': {83: 142.36722}, 'normo': {83: 26.61290322580645}, 'hypo': {83: 9.67741935483871}, 'sev_hypo': {83: 4.838709677419355}, 'hyper': {83: 30.64516129032258}, 'lgbi': {83: 12.355294}, 'hgbi': {83: 29.799648}, 'ri': {83: 42.15494}, 'sev_hyper': {83: 28.225806451612904}}
# {'epi': {83: 168}, 't': {83: 272}, 'reward': {83: 230.8864}, 'normo': {83: 55.14705882352941}, 'hypo': {83: 10.294117647058824}, 'sev_hypo': {83: 1.838235294117647}, 'hyper': {83: 26.83823529411765}, 'lgbi': {83: 6.9750977}, 'hgbi': {83: 12.34306}, 'ri': {83: 19.318157}, 'sev_hyper': {83: 5.882352941176471}}
