# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='sep3_0_normal_128_64', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='sep3_2_normal_128_64', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='sep3_3_normal_128_64', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='sep3_0_normal_128_64_aux', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='sep3_2_normal_128_64_aux', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='sep3_3_normal_128_64_aux', version=1.1, plot_version=1)

command = []
dis_len = 3000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
            '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
                '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
                 '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=288, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 10)

# %%
#debugging a given experimentset_args
target_exp = exp4
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {256: 258}, 't': {256: 2110}, 'reward': {256: 2043.1827}, 'normo': {256: 90.33175355450236}, 'hypo': {256: 4.028436018957346}, 'sev_hypo': {256: 0.3317535545023696}, 'hyper': {256: 5.308056872037914}, 'lgbi': {256: 2.869229}, 'hgbi': {256: 3.3519182}, 'ri': {256: 6.2211475}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 2098}, 'reward': {256: 2037.3977}, 'normo': {256: 90.13346043851288}, 'hypo': {256: 3.622497616777884}, 'sev_hypo': {256: 0.667302192564347}, 'hyper': {256: 5.5767397521449}, 'lgbi': {256: 2.7834284}, 'hgbi': {256: 2.9250894}, 'ri': {256: 5.708518}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 1925}, 'reward': {256: 1867.8463}, 'normo': {256: 90.12987012987011}, 'hypo': {256: 3.064935064935065}, 'sev_hypo': {256: 0.5194805194805194}, 'hyper': {256: 6.285714285714286}, 'lgbi': {256: 2.9404898}, 'hgbi': {256: 2.9336832}, 'ri': {256: 5.874173}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 720}, 'reward': {256: 695.1654}, 'normo': {256: 88.61111111111111}, 'hypo': {256: 5.972222222222222}, 'sev_hypo': {256: 0.6944444444444444}, 'hyper': {256: 4.722222222222222}, 'lgbi': {256: 4.428423}, 'hgbi': {256: 2.685695}, 'ri': {256: 7.1141176}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 2880}, 'reward': {256: 2801.4355}, 'normo': {256: 93.02083333333331}, 'hypo': {256: 3.1944444444444446}, 'sev_hypo': {256: 0.2777777777777778}, 'hyper': {256: 3.5069444444444446}, 'lgbi': {256: 2.788681}, 'hgbi': {256: 2.6865985}, 'ri': {256: 5.47528}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 2880}, 'reward': {256: 2802.664}, 'normo': {256: 94.375}, 'hypo': {256: 0.9375}, 'sev_hypo': {256: 0.0}, 'hyper': {256: 4.6875}, 'lgbi': {256: 1.9604211}, 'hgbi': {256: 3.201549}, 'ri': {256: 5.16197}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 209}, 'reward': {256: 203.12698}, 'normo': {256: 93.77990430622008}, 'hypo': {256: 4.784688995215311}, 'sev_hypo': {256: 1.4354066985645932}, 'hyper': {256: 0.0}, 'lgbi': {256: 4.538063}, 'hgbi': {256: 1.6375716}, 'ri': {256: 6.1756344}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 2880}, 'reward': {256: 2799.723}, 'normo': {256: 92.77777777777776}, 'hypo': {256: 3.8194444444444446}, 'sev_hypo': {256: 0.1736111111111111}, 'hyper': {256: 3.2291666666666665}, 'lgbi': {256: 3.081973}, 'hgbi': {256: 2.6029394}, 'ri': {256: 5.6849127}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 2547}, 'reward': {256: 2468.556}, 'normo': {256: 89.39929328621908}, 'hypo': {256: 3.297997644287397}, 'sev_hypo': {256: 0.1963093835885355}, 'hyper': {256: 7.106399685904986}, 'lgbi': {256: 2.4833066}, 'hgbi': {256: 3.5025678}, 'ri': {256: 5.985874}, 'sev_hyper': {256: 0.0}}
# {'epi': {256: 258}, 't': {256: 2880}, 'reward': {256: 2792.4058}, 'normo': {256: 88.99305555555556}, 'hypo': {256: 3.4027777777777777}, 'sev_hypo': {256: 0.2083333333333333}, 'hyper': {256: 7.395833333333333}, 'lgbi': {256: 2.5038404}, 'hgbi': {256: 3.4433873}, 'ri': {256: 5.9472275}, 'sev_hyper': {256: 0.0}}
