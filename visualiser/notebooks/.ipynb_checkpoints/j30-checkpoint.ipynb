# %%
import os
import sys
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
import pandas as pd
import numpy as np
import json
   
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j30_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='j30_1', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='j30_2', version=1.1, plot_version=1)
#exp4 = ExperimentVisualise(id='j30_3', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='j30_4', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='j30_5', version=1.1, plot_version=1)
# exp7 = ExperimentVisualise(id='j25_6', version=1.1, plot_version=1)
# exp8 = ExperimentVisualise(id='j25_7', version=1.1, plot_version=1)
# exp9 = ExperimentVisualise(id='j25_8', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='j25_9', version=1.1, plot_version=1)

command = []
dis_len = 5000000
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           #'4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
#            '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
#            '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
#            '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#            '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1c0d8a50e209> in <module>
# ----> 1 from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
#       2 from core import plot_episode, plot_training_action_summary, plot_aux_training
#       3 from core import display_commands, plot_testing_metric
#       4 from matplotlib import pyplot as plt
#       5 import matplotlib.gridspec
#
# ModuleNotFoundError: No module named 'core'

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=288)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {95: 192}, 't': {95: 312}, 'reward': {95: 300.88132}, 'normo': {95: 86.85897435897436}, 'hypo': {95: 0.9615384615384616}, 'sev_hypo': {95: 0.0}, 'hyper': {95: 12.17948717948718}, 'lgbi': {95: 1.4700414}, 'hgbi': {95: 6.5732894}, 'ri': {95: 8.043331}, 'sev_hyper': {95: 0.0}}
# {'epi': {95: 192}, 't': {95: 312}, 'reward': {95: 302.37195}, 'normo': {95: 90.06410256410257}, 'hypo': {95: 0.0}, 'sev_hypo': {95: 0.0}, 'hyper': {95: 9.935897435897436}, 'lgbi': {95: 1.1565512}, 'hgbi': {95: 3.9959817}, 'ri': {95: 5.152533}, 'sev_hyper': {95: 0.0}}
# {'epi': {95: 192}, 't': {95: 312}, 'reward': {95: 297.23578}, 'normo': {95: 80.76923076923077}, 'hypo': {95: 0.0}, 'sev_hypo': {95: 0.0}, 'hyper': {95: 19.23076923076923}, 'lgbi': {95: 0.83875424}, 'hgbi': {95: 6.4886684}, 'ri': {95: 7.3274226}, 'sev_hyper': {95: 0.0}}
# {'epi': {95: 192}, 't': {95: 312}, 'reward': {95: 298.18317}, 'normo': {95: 79.16666666666667}, 'hypo': {95: 4.487179487179487}, 'sev_hypo': {95: 0.0}, 'hyper': {95: 16.346153846153847}, 'lgbi': {95: 3.720485}, 'hgbi': {95: 4.883074}, 'ri': {95: 8.603559}, 'sev_hyper': {95: 0.0}}
# {'epi': {95: 192}, 't': {95: 312}, 'reward': {95: 300.3249}, 'normo': {95: 86.53846153846153}, 'hypo': {95: 0.0}, 'sev_hypo': {95: 0.0}, 'hyper': {95: 13.461538461538462}, 'lgbi': {95: 0.34493834}, 'hgbi': {95: 4.635996}, 'ri': {95: 4.980934}, 'sev_hyper': {95: 0.0}}
