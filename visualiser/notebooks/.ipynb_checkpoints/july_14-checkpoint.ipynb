# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='july15_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='july15_2', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='july15_3', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='july15_0_nobgp', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='july15_2_nobgp', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='july15_3_nobgp', version=1.1, plot_version=1)
# exp7 = ExperimentVisualise(id='july9_6', version=1.1, plot_version=1)
# exp8 = ExperimentVisualise(id='july9_7', version=1.1, plot_version=1)
# exp9 = ExperimentVisualise(id='july9_8', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='july9_9', version=1.1, plot_version=1)

command = []
#command = ['off c lime brown orange']
dis_len = 2000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
            '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
            '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
             '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
#             '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
#             '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
#             '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#             '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 10)

# %%
# debugging a given experimentset_args
target_exp = exp3
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {113: 228}, 't': {113: 76}, 'reward': {113: 69.61256}, 'normo': {113: 71.05263157894737}, 'hypo': {113: 25.0}, 'sev_hypo': {113: 3.947368421052632}, 'hyper': {113: 0.0}, 'lgbi': {113: 8.398071}, 'hgbi': {113: 1.4210248}, 'ri': {113: 9.819096}, 'sev_hyper': {113: 0.0}}
# {'epi': {113: 228}, 't': {113: 49}, 'reward': {113: 40.87526}, 'normo': {113: 34.69387755102041}, 'hypo': {113: 8.16326530612245}, 'sev_hypo': {113: 4.081632653061225}, 'hyper': {113: 53.06122448979592}, 'lgbi': {113: 12.6038}, 'hgbi': {113: 14.2771015}, 'ri': {113: 26.880901}, 'sev_hyper': {113: 0.0}}
# {'epi': {113: 228}, 't': {113: 115}, 'reward': {113: 106.19431}, 'normo': {113: 66.95652173913044}, 'hypo': {113: 5.217391304347826}, 'sev_hypo': {113: 2.608695652173913}, 'hyper': {113: 25.217391304347824}, 'lgbi': {113: 7.472644}, 'hgbi': {113: 5.4031434}, 'ri': {113: 12.875788}, 'sev_hyper': {113: 0.0}}
# {'epi': {113: 228}, 't': {113: 196}, 'reward': {113: 176.59973}, 'normo': {113: 78.06122448979592}, 'hypo': {113: 6.122448979591836}, 'sev_hypo': {113: 5.1020408163265305}, 'hyper': {113: 10.714285714285714}, 'lgbi': {113: 6.6951623}, 'hgbi': {113: 5.684665}, 'ri': {113: 12.3798275}, 'sev_hyper': {113: 0.0}}
# {'epi': {113: 228}, 't': {113: 52}, 'reward': {113: 23.499529}, 'normo': {113: 28.846153846153847}, 'hypo': {113: 3.8461538461538463}, 'sev_hypo': {113: 13.461538461538462}, 'hyper': {113: 17.307692307692307}, 'lgbi': {113: 22.146103}, 'hgbi': {113: 31.438684}, 'ri': {113: 53.584785}, 'sev_hyper': {113: 36.53846153846154}}
