# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training, plot_planning_training
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2, plot_testing_average_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue, maroon, navyblue = '#483D8B', '#800000', '#000080'
darkgreen =  '#006400'

exp1 = ExperimentVisualise(id='nov5_lambda_99', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='nov5_lambda_95', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='nov5_lambda_90', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='nov5_lambda_85', version=1.1, plot_version=1, test_seeds=5000)
exp5 = ExperimentVisualise(id='nov5_lambda_80', version=1.1, plot_version=1, test_seeds=5000)
exp6 = ExperimentVisualise(id='nov5_lambda_70', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='nov5_lambda_50', version=1.1, plot_version=1, test_seeds=5000)

exp8 = ExperimentVisualise(id='nov6_monthly_steps', version=1.1, plot_version=1, test_seeds=5000)
exp9 = ExperimentVisualise(id='nov6_short_obsv_hypo_penalty_lstm16', version=1.1, plot_version=1, test_seeds=5000)

exp10 = ExperimentVisualise(id='nov6_short_obsv_hypo_penalty_lstm16_rewL', version=1.1, plot_version=1, test_seeds=5000)
exp11 = ExperimentVisualise(id='nov6_short_obsv_hypo_penalty_lstm16_ZeroPenal', version=1.1, plot_version=1, test_seeds=5000)

exp12 = ExperimentVisualise(id='nov6_short_obsv_hypo_penalty_lstm16_98gamma', version=1.1, plot_version=1, test_seeds=5000)

exp13 = ExperimentVisualise(id='nov6_short_obsv_hypo_penalty_lstm16_95gamma', version=1.1, plot_version=1, test_seeds=5000)
exp14 = ExperimentVisualise(id='nov6_short_obsv_hypo_penalty_lstm16_97gamma', version=1.1, plot_version=1, test_seeds=5000)
exp15 = ExperimentVisualise(id='nov6_short_obsv_hypo_penalty_lstm16_90gamma', version=1.1, plot_version=1, test_seeds=5000)


# plot the graphs
dis_len = 14 * 1000000
command = []
disp_arr = display_commands_v2(command)
exp_vis = {
#             '1':{ "id":exp1, "color":darkgreen,"show": disp_arr[1], "label":''}, 
#             '2':{ "id":exp2, "color":maroon,"show": disp_arr[2], "label":''},  
#             '3':{ "id":exp3, "color":'r',"show": disp_arr[3], "label":''}, 
#             '4':{ "id":exp4, "color":'b',"show": disp_arr[4], "label":''},  
#             '5':{ "id":exp5, "color":'k',"show": disp_arr[5], "label":''}, 
#             '6':{ "id":exp6, "color":'c',"show": disp_arr[6], "label":''}, 
#             '7':{ "id":exp7, "color":'m',"show": disp_arr[7], "label":''}, 
           
       # '8':{ "id":exp8, "color":'r',"show": disp_arr[8], "label":''}, 
      #'10':{ "id":exp10, "color":'g',"show": disp_arr[10], "label":''}, 
    #'11':{ "id":exp11, "color":'m',"show": disp_arr[11], "label":''},
    
            '9':{ "id":exp9, "color":'b',"show": disp_arr[9], "label":'Adult1 gamma 0.997'}, 
     '12':{ "id":exp12, "color":'g',"show": disp_arr[12], "label":'Adult1 gamma 0.98'}, 
    '14':{ "id":exp14, "color":'k',"show": disp_arr[14], "label":'Adult1 gamma 0.97'}, 
    '13':{ "id":exp13, "color":brown,"show": disp_arr[13], "label":'Adult1 gamma 0.95'}, 
    '15':{ "id":exp15, "color":'r',"show": disp_arr[15], "label":'Adult1 gamma 0.90'}, 
         
            
}
#groups = [['3', '7','10', '11'], ['12', '13','14']]
#plot_testing_average_metric(exp_vis, groups, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)


plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True, label=True)  # normal
plot_training_logs(exp_vis, dis_len, version=3)
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=70, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)

# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='aBGP_rmse', goal=5, fill=False)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='cBGP_rmse', goal=5, fill=False)
# plot_aux_training(exp_vis, 500, 1)

# plot_planning_training(exp_vis, 500, 1)

# %%
## debugging a given experimentset_args
target_exp = exp13
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256 * 30)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=256 * 30)
# Out:
#  Experiment summary...
# {'epi': {150: 152}, 't': {150: 312}, 'reward': {150: 196.80789}, 'normo': {150: 56.73076923076923}, 'hypo': {150: 2.243589743589744}, 'sev_hypo': {150: 0.0}, 'hyper': {150: 38.782051282051285}, 'lgbi': {150: 3.147157}, 'hgbi': {150: 8.9919615}, 'ri': {150: 12.139118}, 'sev_hyper': {150: 2.243589743589744}, 'aBGP_rmse': {150: 129.40128}, 'cBGP_rmse': {150: 198.40923}}
# {'epi': {150: 152}, 't': {150: 312}, 'reward': {150: 228.51024}, 'normo': {150: 69.87179487179488}, 'hypo': {150: 1.2820512820512822}, 'sev_hypo': {150: 0.0}, 'hyper': {150: 23.07692307692308}, 'lgbi': {150: 1.5882232}, 'hgbi': {150: 14.012762}, 'ri': {150: 15.600986}, 'sev_hyper': {150: 5.769230769230769}, 'aBGP_rmse': {150: 143.03888}, 'cBGP_rmse': {150: 209.85852}}
# ...
