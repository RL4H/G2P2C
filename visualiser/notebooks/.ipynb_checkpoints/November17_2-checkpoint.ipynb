# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_training_logs
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2, plot_testing_average_metric
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue, maroon, navyblue = '#483D8B', '#800000', '#000080'
darkgreen =  '#006400'

exp1 = ExperimentVisualise(id='nov17_embc_A1_v5', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='nov17_embc_A2_v5', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='nov17_embc_A3_v5', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='nov17_embc_A4_v5', version=1.1, plot_version=1, test_seeds=5000)
exp5 = ExperimentVisualise(id='nov17_embc_A9_v5', version=1.1, plot_version=1, test_seeds=5000)

# plot the graphs
dis_len = 1.5* 1000000
command = []
disp_arr = display_commands_v2(command)
exp_vis = {
             '1':{ "id":exp1, "color":darkgreen,"show": disp_arr[1], "label":''}, 
              '2':{ "id":exp2, "color":navyblue,"show": disp_arr[2], "label":''},  
             '3':{ "id":exp3, "color":'r',"show": disp_arr[3], "label":''}, 
             '4':{ "id":exp4, "color":'m',"show": disp_arr[4], "label":''},  
              '5':{ "id":exp5, "color":'k',"show": disp_arr[5], "label":''}, 

}
#groups = [['3', '7','10', '11'], ['12', '13','14']]
#plot_testing_average_metric(exp_vis, groups, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)


plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True, label=False)  # normal

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=70, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='hgbi', goal=5, fill=False)
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='lgbi', goal=1.1, fill=False)
#plot_training_logs(exp_vis, dis_len, version=3)

params = ['exp_var', 'true_var','val_loss', 'policy_grad', 'value_grad', 'pi_loss']
plot_training_logs(mode='ppo', exp_dict=exp_vis, dis_len=dis_len, params=params)

# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='aBGP_rmse', goal=5, fill=False)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='cBGP_rmse', goal=5, fill=False)

# plot_aux_training(exp_vis, 500, 1)
# plot_planning_training(exp_vis, 500, 1)

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=256)
# Out:
#  Experiment summary...
# {'epi': {182: 184}, 't': {182: 312}, 'reward': {182: 244.52643}, 'normo': {182: 46.7948717948718}, 'hypo': {182: 0.0}, 'sev_hypo': {182: 0.0}, 'hyper': {182: 52.24358974358975}, 'lgbi': {182: 0.016947547}, 'hgbi': {182: 8.840977}, 'ri': {182: 8.857924}, 'sev_hyper': {182: 0.9615384615384616}, 'aBGP_rmse': {182: 176.21527}, 'cBGP_rmse': {182: 150.3252}}
# {'epi': {182: 184}, 't': {182: 312}, 'reward': {182: 236.6135}, 'normo': {182: 44.55128205128205}, 'hypo': {182: 0.0}, 'sev_hypo': {182: 0.0}, 'hyper': {182: 54.80769230769231}, 'lgbi': {182: 2.5010207}, 'hgbi': {182: 11.461331}, 'ri': {182: 13.962352}, 'sev_hyper': {182: 0.6410256410256411}, 'aBGP_rmse': {182: 183.85544}, 'cBGP_rmse': {182: 158.55563}}
# {'epi': {182: 184}, 't': {182: 312}, 'reward': {182: 261.17377}, 'normo': {182: 69.23076923076923}, 'hypo': {182: 6.089743589743589}, 'sev_hypo': {182: 1.2820512820512822}, 'hyper': {182: 23.397435897435894}, 'lgbi': {182: 5.9156947}, 'hgbi': {182: 6.2987504}, 'ri': {182: 12.214445}, 'sev_hyper': {182: 0.0}, 'aBGP_rmse': {182: 219.63701}, 'cBGP_rmse': {182: 193.58041}}
# {'epi': {182: 184}, 't': {182: 312}, 'reward': {182: 249.5722}, 'normo': {182: 64.1025641025641}, 'hypo': {182: 0.0}, 'sev_hypo': {182: 0.0}, 'hyper': {182: 27.884615384615383}, 'lgbi': {182: 1.3947647}, 'hgbi': {182: 12.511441}, 'ri': {182: 13.906206}, 'sev_hyper': {182: 8.012820512820513}, 'aBGP_rmse': {182: 198.96854}, 'cBGP_rmse': {182: 174.20862}}
# {'epi': {182: 184}, 't': {182: 312}, 'reward': {182: 232.69173}, 'normo': {182: 48.3974358974359}, 'hypo': {182: 2.8846153846153846}, 'sev_hypo': {182: 0.0}, 'hyper': {182: 45.19230769230769}, 'lgbi': {182: 3.487056}, 'hgbi': {182: 13.78712}, 'ri': {182: 17.274176}, 'sev_hyper': {182: 3.525641025641025}, 'aBGP_rmse': {182: 185.26176}, 'cBGP_rmse': {182: 160.47763}}
# {'epi': {182: 184}, 't': {182: 312}, 'reward': {182: 233.53214}, 'normo': {182: 52.56410256410256}, 'hypo': {182: 2.8846153846153846}, 'sev_hypo': {182: 0.0}, 'hyper': {182: 41.34615384615385}, 'lgbi': {182: 4.343496}, 'hgbi': {182: 11.714705}, 'ri': {182: 16.0582}, 'sev_hyper': {182: 3.2051282051282053}, 'aBGP_rmse': {182: 186.81618}, 'cBGP_rmse': {182: 161.87299}}
# {'epi': {181: 183}, 't': {181: 312}, 'reward': {181: 286.02228}, 'normo': {181: 84.61538461538461}, 'hypo': {181: 3.525641025641025}, 'sev_hypo': {181: 0.0}, 'hyper': {181: 11.85897435897436}, 'lgbi': {181: 2.8472254}, 'hgbi': {181: 4.786053}, 'ri': {181: 7.633279}, 'sev_hyper': {181: 0.0}, 'aBGP_rmse': {181: 225.08817}, 'cBGP_rmse': {181: 198.64813}}
# {'epi': {181: 183}, 't': {181: 254}, 'reward': {181: 205.64095}, 'normo': {181: 65.35433070866142}, 'hypo': {181: 11.811023622047244}, 'sev_hypo': {181: 2.3622047244094486}, 'hyper': {181: 20.47244094488189}, 'lgbi': {181: 10.210191}, 'hgbi': {181: 5.420982}, 'ri': {181: 15.631172}, 'sev_hyper': {181: 0.0}, 'aBGP_rmse': {181: 218.67397}, 'cBGP_rmse': {181: 192.4979}}
# {'epi': {181: 183}, 't': {181: 312}, 'reward': {181: 237.16241}, 'normo': {181: 58.97435897435897}, 'hypo': {181: 9.294871794871796}, 'sev_hypo': {181: 0.0}, 'hyper': {181: 31.73076923076923}, 'lgbi': {181: 4.1139235}, 'hgbi': {181: 13.509468}, 'ri': {181: 17.623392}, 'sev_hyper': {181: 0.0}, 'aBGP_rmse': {181: 220.58624}, 'cBGP_rmse': {181: 195.05614}}
# {'epi': {181: 183}, 't': {181: 312}, 'reward': {181: 214.04161}, 'normo': {181: 39.74358974358975}, 'hypo': {181: 0.0}, 'sev_hypo': {181: 0.0}, 'hyper': {181: 50.0}, 'lgbi': {181: 0.31922144}, 'hgbi': {181: 14.900972}, 'ri': {181: 15.220194}, 'sev_hyper': {181: 10.256410256410255}, 'aBGP_rmse': {181: 167.65146}, 'cBGP_rmse': {181: 143.28612}}
