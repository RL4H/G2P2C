# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='sep29_5_LH_1024batch', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='sep29_5_LH_1024batch_addfeat3', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='sep29_5_LH_1024batch_only_lstm', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='sep29_5_SH_1024batch_only_lstm', version=1.1, plot_version=1, test_seeds=5000)

exp5 = ExperimentVisualise(id='sep28_5_exp10', version=1.1, plot_version=1, test_seeds=5000)
exp6 = ExperimentVisualise(id='sep28_5_exp11', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='sep29_5_exp12', version=1.1, plot_version=1, test_seeds=5000)
exp8 = ExperimentVisualise(id='sep29_5_exp13', version=1.1, plot_version=1, test_seeds=5000)
exp9 = ExperimentVisualise(id='sep29_5_exp14', version=1.1, plot_version=1, test_seeds=5000)
exp10 = ExperimentVisualise(id='sep29_5_exp15', version=1.1, plot_version=1, test_seeds=5000)
exp11 = ExperimentVisualise(id='sep29_5_exp16', version=1.1, plot_version=1, test_seeds=5000)

# exp1 = ExperimentVisualise(id='sep28_5_reward_window_average', version=1.1, plot_version=1, test_seeds=5000)
# exp2 = ExperimentVisualise(id='sep28_5_exp7_reward_window_marginal', version=1.1, plot_version=1, test_seeds=5000)
# exp3 = ExperimentVisualise(id='sep28_5_reward_window_ema', version=1.1, plot_version=1, test_seeds=5000)
# exp4 = ExperimentVisualise(id='sep28_5_reward_window_ema_5', version=1.1, plot_version=1, test_seeds=5000)

command = ['off k c']  


#command = []  
dis_len = 5 * 1000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
             '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
              '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
              '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
#              '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
#              '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
#            '7':{ "id":exp7,"color":brown,"show": disp_arr[6]},
#             '8':{ "id":exp8,"color":pink,"show": disp_arr[7]},
#            '9':{ "id":exp9,"color":'g',"show": disp_arr[7]},
          #'10':{ "id":exp10,"color":orange,"show": disp_arr[7]},
         # '11':{ "id":exp11,"color":'r',"show": disp_arr[7]},
          }

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=True)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 10)

# %%
#debugging a given experimentset_args
target_exp = exp3
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {6: 8}, 't': {6: 49}, 'reward': {6: 44.922558}, 'normo': {6: 67.34693877551021}, 'hypo': {6: 8.16326530612245}, 'sev_hypo': {6: 8.16326530612245}, 'hyper': {6: 16.3265306122449}, 'lgbi': {6: 13.733396}, 'hgbi': {6: 4.1160383}, 'ri': {6: 17.849434}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 34}, 'reward': {6: 30.39562}, 'normo': {6: 64.70588235294117}, 'hypo': {6: 14.705882352941176}, 'sev_hypo': {6: 20.58823529411765}, 'hyper': {6: 0.0}, 'lgbi': {6: 14.462514}, 'hgbi': {6: 0.5481246}, 'ri': {6: 15.010638}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 49}, 'reward': {6: 46.605293}, 'normo': {6: 89.79591836734694}, 'hypo': {6: 6.122448979591836}, 'sev_hypo': {6: 4.081632653061225}, 'hyper': {6: 0.0}, 'lgbi': {6: 5.5978556}, 'hgbi': {6: 1.3968941}, 'ri': {6: 6.9947495}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 43}, 'reward': {6: 39.798286}, 'normo': {6: 81.3953488372093}, 'hypo': {6: 11.627906976744184}, 'sev_hypo': {6: 6.976744186046512}, 'hyper': {6: 0.0}, 'lgbi': {6: 13.490706}, 'hgbi': {6: 2.3966706}, 'ri': {6: 15.887377}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 29}, 'reward': {6: 26.705414}, 'normo': {6: 86.20689655172414}, 'hypo': {6: 6.896551724137931}, 'sev_hypo': {6: 6.896551724137931}, 'hyper': {6: 0.0}, 'lgbi': {6: 8.111291}, 'hgbi': {6: 2.9138792}, 'ri': {6: 11.02517}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 28}, 'reward': {6: 25.41424}, 'normo': {6: 75.0}, 'hypo': {6: 14.285714285714286}, 'sev_hypo': {6: 10.714285714285714}, 'hyper': {6: 0.0}, 'lgbi': {6: 12.143438}, 'hgbi': {6: 1.1251466}, 'ri': {6: 13.268585}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 71}, 'reward': {6: 66.92126}, 'normo': {6: 73.2394366197183}, 'hypo': {6: 14.084507042253522}, 'sev_hypo': {6: 2.816901408450704}, 'hyper': {6: 9.859154929577464}, 'lgbi': {6: 6.265771}, 'hgbi': {6: 3.1784873}, 'ri': {6: 9.444258}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 52}, 'reward': {6: 48.82499}, 'normo': {6: 76.92307692307692}, 'hypo': {6: 19.23076923076923}, 'sev_hypo': {6: 3.8461538461538463}, 'hyper': {6: 0.0}, 'lgbi': {6: 9.2253685}, 'hgbi': {6: 0.59819216}, 'ri': {6: 9.823561}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 55}, 'reward': {6: 50.861706}, 'normo': {6: 70.9090909090909}, 'hypo': {6: 3.636363636363636}, 'sev_hypo': {6: 5.454545454545454}, 'hyper': {6: 20.0}, 'lgbi': {6: 9.278107}, 'hgbi': {6: 5.3158174}, 'ri': {6: 14.593924}, 'sev_hyper': {6: 0.0}}
# {'epi': {6: 8}, 't': {6: 48}, 'reward': {6: 42.639404}, 'normo': {6: 56.25}, 'hypo': {6: 4.166666666666667}, 'sev_hypo': {6: 6.25}, 'hyper': {6: 33.333333333333336}, 'lgbi': {6: 7.293293}, 'hgbi': {6: 11.299214}, 'ri': {6: 18.592506}, 'sev_hyper': {6: 0.0}}
