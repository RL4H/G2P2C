# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j16_0_nocarb_history', version=1.1)
exp2 = ExperimentVisualise(id='j16_1_nocarb_history', version=1.1)
exp3 = ExperimentVisualise(id='j16_2_nocarb_history', version=1.1)
exp4 = ExperimentVisualise(id='j16_3_nocarb_history', version=1.1)
exp5 = ExperimentVisualise(id='j16_4_nocarb_history', version=1.1)
exp6 = ExperimentVisualise(id='j16_5_nocarb_history', version=1.1)

command = []
dis_len = 5000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]} }
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_testing_metric(exp_vis, 'min_max', dis_len, 'normo', 75)  # min_max, normal
plot_testing_metric(exp_vis, 'min_max', dis_len, 'ri', 5)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp2
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 516
plot_episode(target_exp, tester=0, episode=target_epi)
plot_episode(target_exp, tester=1, episode=target_epi)
plot_episode(target_exp, tester=2, episode=target_epi)
plot_episode(target_exp, tester=3, episode=target_epi)
plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {257: 516}, 't': {257: 234}, 'reward': {257: 156.69144}, 'normo': {257: 18.803418803418804}, 'hypo': {257: 12.393162393162394}, 'sev_hypo': {257: 2.9914529914529915}, 'hyper': {257: 68.80341880341881}, 'lgbi': {257: 14.043084}, 'hgbi': {257: 36.990597}, 'ri': {257: 51.03368}}
# {'epi': {257: 516}, 't': {257: 219}, 'reward': {257: 151.666}, 'normo': {257: 27.85388127853881}, 'hypo': {257: 8.219178082191782}, 'sev_hypo': {257: 3.1963470319634704}, 'hyper': {257: 63.92694063926941}, 'lgbi': {257: 10.11525}, 'hgbi': {257: 35.00502}, 'ri': {257: 45.12027}}
# {'epi': {257: 516}, 't': {257: 100}, 'reward': {257: 56.83541}, 'normo': {257: 15.0}, 'hypo': {257: 0.0}, 'sev_hypo': {257: 0.0}, 'hyper': {257: 85.0}, 'lgbi': {257: 1.0235641}, 'hgbi': {257: 46.335926}, 'ri': {257: 47.35949}}
# {'epi': {257: 516}, 't': {257: 123}, 'reward': {257: 96.88011}, 'normo': {257: 45.52845528455285}, 'hypo': {257: 0.0}, 'sev_hypo': {257: 0.0}, 'hyper': {257: 54.47154471544715}, 'lgbi': {257: 0.0}, 'hgbi': {257: 21.235256}, 'ri': {257: 21.235256}}
# {'epi': {257: 516}, 't': {257: 288}, 'reward': {257: 220.51355}, 'normo': {257: 40.27777777777778}, 'hypo': {257: 0.3472222222222222}, 'sev_hypo': {257: 0.0}, 'hyper': {257: 59.375}, 'lgbi': {257: 1.7806486}, 'hgbi': {257: 28.775524}, 'ri': {257: 30.556173}}
