# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training, plot_planning_training
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2, plot_testing_average_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue, maroon, navyblue = '#483D8B', '#800000', '#000080'
darkgreen =  '#006400'

exp1 = ExperimentVisualise(id='nov16_diffRew_avg_A1_originalRew_decay', version=1.1, plot_version=1, test_seeds=5000)

#exp1 = ExperimentVisualise(id='nov12_expRew_avg_uni_adult1', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='nov12_expRew_discount_uni_adult1', version=1.1, plot_version=1, test_seeds=5000)

exp3 = ExperimentVisualise(id='nov12_diffRew_avg_A1', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='nov12_diffRew_avg_A2', version=1.1, plot_version=1, test_seeds=5000)
exp5 = ExperimentVisualise(id='nov12_diffRew_avg_A3', version=1.1, plot_version=1, test_seeds=5000)
exp6 = ExperimentVisualise(id='nov12_diffRew_dis_A1', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='nov12_diffRew_dis_A2', version=1.1, plot_version=1, test_seeds=5000)

exp8 = ExperimentVisualise(id='nov13_diffRew_avg_A1_e2', version=1.1, plot_version=1, test_seeds=5000)
exp9 = ExperimentVisualise(id='nov13_diffRew_avg_A1_e4', version=1.1, plot_version=1, test_seeds=5000)


exp10 = ExperimentVisualise(id='nov15_2diffRew_avg_A1', version=1.1, plot_version=1, test_seeds=5000)
exp11 = ExperimentVisualise(id='nov15_2diffRew_avg_A2', version=1.1, plot_version=1, test_seeds=5000)
exp12 = ExperimentVisualise(id='nov15_2diffRew_avg_A3', version=1.1, plot_version=1, test_seeds=5000)
exp13 = ExperimentVisualise(id='nov15_2diffRew_avg_A1_noPenalty', version=1.1, plot_version=1, test_seeds=5000)
exp14 = ExperimentVisualise(id='nov15_2diffRew_avg_A1_hyperPenalty', version=1.1, plot_version=1, test_seeds=5000)
exp15 = ExperimentVisualise(id='nov15_2diffRew_avg_A1_noPenalty_24lstm', version=1.1, plot_version=1, test_seeds=5000)
exp16 = ExperimentVisualise(id='nov15_2diffRew_dis_A1_noPenalty_24lstm', version=1.1, plot_version=1, test_seeds=5000)
exp17 = ExperimentVisualise(id='nov15_diffRew_avg_A1_noPenalty_simpleRew', version=1.1, plot_version=1, test_seeds=5000)

exp18 = ExperimentVisualise(id='nov16_diffRew_avg_A1_originalRew_noMA_lstm12', version=1.1, plot_version=1, test_seeds=5000)
exp19 = ExperimentVisualise(id='nov16_diffRew_avg_A1_originalRew_24lstm', version=1.1, plot_version=1, test_seeds=5000)
exp20 = ExperimentVisualise(id='nov16_diffRew_avg_A1_originalRew', version=1.1, plot_version=1, test_seeds=5000)


# plot the graphs
dis_len = 2.5* 1000000
#command = ['only 3 8 9']  # comparing reward lr; for simple reward
command = ['only 10 13 14 15 16']
command = ['only 17 18 19 20 1']
#command = ['only 16']
disp_arr = display_commands_v2(command)
exp_vis = {
             '1':{ "id":exp1, "color":darkgreen,"show": disp_arr[1], "label":''}, 
             #'2':{ "id":exp2, "color":maroon,"show": disp_arr[2], "label":''},  
            
#             '3':{ "id":exp3, "color":'r',"show": disp_arr[3], "label":''}, 
#              '4':{ "id":exp4, "color":'b',"show": disp_arr[4], "label":''},  
#               '5':{ "id":exp5, "color":'k',"show": disp_arr[5], "label":''}, 
             '6':{ "id":exp6, "color":'m',"show": disp_arr[6], "label":''}, 
            '7':{ "id":exp7, "color":'c',"show": disp_arr[7], "label":''}, 
    
    
#         '8':{ "id":exp8, "color":'m',"show": disp_arr[8], "label":''}, 
#             '9':{ "id":exp9, "color":'c',"show": disp_arr[9], "label":''}, 
    
    
            # '10':{ "id":exp10, "color":'m',"show": disp_arr[10], "label":''}, 
#              '11':{ "id":exp11, "color":'c',"show": disp_arr[11], "label":''},  
#              '12':{ "id":exp12, "color":'g',"show": disp_arr[12], "label":''}, 
    
          #  '13':{ "id":exp13, "color":orange,"show": disp_arr[13], "label":''}, 
             '14':{ "id":exp14, "color":'b',"show": disp_arr[14], "label":''},
           #  '15':{ "id":exp15, "color":'k',"show": disp_arr[15], "label":''},
             '16':{ "id":exp16, "color":'r',"show": disp_arr[16], "label":''},
             '17':{ "id":exp17, "color":'g',"show": disp_arr[17], "label":''},
    
    
              '18':{ "id":exp18, "color":'m',"show": disp_arr[18], "label":''},
                  '19':{ "id":exp19, "color":'k',"show": disp_arr[19], "label":''},
                '20':{ "id":exp20, "color":'b',"show": disp_arr[20], "label":''},
    
    

}
#groups = [['3', '7','10', '11'], ['12', '13','14']]
#plot_testing_average_metric(exp_vis, groups, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)


plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True, label=False)  # normal

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=70, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='hgbi', goal=5, fill=False)
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='lgbi', goal=1.1, fill=False)
plot_training_logs(exp_vis, dis_len, version=3)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='aBGP_rmse', goal=5, fill=False)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='cBGP_rmse', goal=5, fill=False)
# plot_aux_training(exp_vis, 500, 1)

# plot_planning_training(exp_vis, 500, 1)

# %%
# debugging a given experimentset_args
target_exp = exp18
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=256)
# Out:
#  Experiment summary...
# {'epi': {311: 313}, 't': {311: 312}, 'reward': {311: 274.41724}, 'normo': {311: 50.96153846153846}, 'hypo': {311: 0.0}, 'sev_hypo': {311: 0.0}, 'hyper': {311: 41.34615384615385}, 'lgbi': {311: 1.5860708}, 'hgbi': {311: 12.996638}, 'ri': {311: 14.582709}, 'sev_hyper': {311: 7.6923076923076925}, 'aBGP_rmse': {311: 166.84605}, 'cBGP_rmse': {311: 132.02951}}
# {'epi': {311: 313}, 't': {311: 312}, 'reward': {311: 278.2331}, 'normo': {311: 56.73076923076923}, 'hypo': {311: 0.0}, 'sev_hypo': {311: 0.0}, 'hyper': {311: 32.05128205128205}, 'lgbi': {311: 0.5575095}, 'hgbi': {311: 11.60146}, 'ri': {311: 12.15897}, 'sev_hyper': {311: 11.217948717948715}, 'aBGP_rmse': {311: 172.44804}, 'cBGP_rmse': {311: 137.48927}}
# ...
