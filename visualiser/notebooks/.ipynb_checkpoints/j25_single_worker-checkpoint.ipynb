# %%
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
import pandas as pd
import numpy as np
import json
   
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j25_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='j25_1', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='j25_2', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='j25_3', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='j25_4', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='j25_5', version=1.1, plot_version=1)
exp7 = ExperimentVisualise(id='j25_6', version=1.1, plot_version=1)
exp8 = ExperimentVisualise(id='j25_7', version=1.1, plot_version=1)
exp9 = ExperimentVisualise(id='j25_8', version=1.1, plot_version=1)
exp10 = ExperimentVisualise(id='j25_9', version=1.1, plot_version=1)

command = []
dis_len = 5000000
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
           '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
           '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
           '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
           '10':{ "id":exp10,"color": pink,"show": disp_arr[9]},
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=10000)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=20000)
# Out:
#  Experiment summary...
# {'epi': {37: 76}, 't': {37: 32}, 'reward': {37: 27.96156}, 'normo': {37: 78.125}, 'hypo': {37: 12.5}, 'sev_hypo': {37: 9.375}, 'hyper': {37: 0.0}, 'lgbi': {37: 11.177192}, 'hgbi': {37: 1.2996063}, 'ri': {37: 12.476798}, 'sev_hyper': {37: 0.0}}
# {'epi': {37: 76}, 't': {37: 40}, 'reward': {37: 34.181423}, 'normo': {37: 50.0}, 'hypo': {37: 10.0}, 'sev_hypo': {37: 7.5}, 'hyper': {37: 32.5}, 'lgbi': {37: 15.309576}, 'hgbi': {37: 7.2257943}, 'ri': {37: 22.53537}, 'sev_hyper': {37: 0.0}}
# {'epi': {37: 76}, 't': {37: 31}, 'reward': {37: 26.690126}, 'normo': {37: 74.19354838709677}, 'hypo': {37: 16.129032258064516}, 'sev_hypo': {37: 9.67741935483871}, 'hyper': {37: 0.0}, 'lgbi': {37: 12.296641}, 'hgbi': {37: 3.3085938}, 'ri': {37: 15.605235}, 'sev_hyper': {37: 0.0}}
# {'epi': {37: 76}, 't': {37: 33}, 'reward': {37: 29.726223}, 'normo': {37: 84.84848484848484}, 'hypo': {37: 9.090909090909092}, 'sev_hypo': {37: 6.0606060606060606}, 'hyper': {37: 0.0}, 'lgbi': {37: 10.735328}, 'hgbi': {37: 2.6849418}, 'ri': {37: 13.420269}, 'sev_hyper': {37: 0.0}}
# {'epi': {37: 76}, 't': {37: 30}, 'reward': {37: 25.832508}, 'normo': {37: 73.33333333333333}, 'hypo': {37: 16.666666666666668}, 'sev_hypo': {37: 10.0}, 'hyper': {37: 0.0}, 'lgbi': {37: 12.919173}, 'hgbi': {37: 2.5007932}, 'ri': {37: 15.419967}, 'sev_hyper': {37: 0.0}}
