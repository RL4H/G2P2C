# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='aug17_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='aug17_2', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='aug17_3', version=1.1, plot_version=1)
# exp4 = ExperimentVisualise(id='aug3_3', version=1.1, plot_version=1)
# exp5 = ExperimentVisualise(id='aug3_4', version=1.1, plot_version=1)
# exp6 = ExperimentVisualise(id='aug3_5', version=1.1, plot_version=1)

command = []
dis_len = 10000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
#             '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
#              '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
#               '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 10)

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {128: 130}, 't': {128: 26}, 'reward': {128: -6.432331}, 'normo': {128: 73.07692307692308}, 'hypo': {128: 19.23076923076923}, 'sev_hypo': {128: 7.6923076923076925}, 'hyper': {128: 0.0}, 'lgbi': {128: 15.04528}, 'hgbi': {128: 1.9363952}, 'ri': {128: 16.981676}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 25}, 'reward': {128: -7.159542}, 'normo': {128: 80.0}, 'hypo': {128: 12.0}, 'sev_hypo': {128: 8.0}, 'hyper': {128: 0.0}, 'lgbi': {128: 13.992008}, 'hgbi': {128: 1.7642636}, 'ri': {128: 15.756271}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 54}, 'reward': {128: 18.671486}, 'normo': {128: 70.37037037037037}, 'hypo': {128: 11.11111111111111}, 'sev_hypo': {128: 18.51851851851852}, 'hyper': {128: 0.0}, 'lgbi': {128: 11.185432}, 'hgbi': {128: 1.688363}, 'ri': {128: 12.8737955}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 24}, 'reward': {128: -8.54302}, 'normo': {128: 66.66666666666667}, 'hypo': {128: 8.333333333333334}, 'sev_hypo': {128: 8.333333333333334}, 'hyper': {128: 16.666666666666668}, 'lgbi': {128: 10.653605}, 'hgbi': {128: 6.140568}, 'ri': {128: 16.794174}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 26}, 'reward': {128: -6.3011494}, 'normo': {128: 76.92307692307692}, 'hypo': {128: 11.538461538461538}, 'sev_hypo': {128: 11.538461538461538}, 'hyper': {128: 0.0}, 'lgbi': {128: 12.072679}, 'hgbi': {128: 1.6746395}, 'ri': {128: 13.747318}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 27}, 'reward': {128: -5.491024}, 'normo': {128: 77.77777777777777}, 'hypo': {128: 11.11111111111111}, 'sev_hypo': {128: 11.11111111111111}, 'hyper': {128: 0.0}, 'lgbi': {128: 11.706023}, 'hgbi': {128: 2.5090268}, 'ri': {128: 14.21505}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 29}, 'reward': {128: -3.7074833}, 'normo': {128: 79.3103448275862}, 'hypo': {128: 10.344827586206897}, 'sev_hypo': {128: 10.344827586206897}, 'hyper': {128: 0.0}, 'lgbi': {128: 12.656808}, 'hgbi': {128: 2.1170022}, 'ri': {128: 14.77381}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 28}, 'reward': {128: -4.5192413}, 'normo': {128: 78.57142857142857}, 'hypo': {128: 14.285714285714286}, 'sev_hypo': {128: 7.142857142857143}, 'hyper': {128: 0.0}, 'lgbi': {128: 11.493528}, 'hgbi': {128: 2.7140312}, 'ri': {128: 14.20756}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 25}, 'reward': {128: -7.37537}, 'normo': {128: 76.0}, 'hypo': {128: 12.0}, 'sev_hypo': {128: 12.0}, 'hyper': {128: 0.0}, 'lgbi': {128: 15.564621}, 'hgbi': {128: 1.3395218}, 'ri': {128: 16.904142}, 'sev_hyper': {128: 0.0}}
# {'epi': {128: 130}, 't': {128: 23}, 'reward': {128: -8.892704}, 'normo': {128: 82.6086956521739}, 'hypo': {128: 8.695652173913043}, 'sev_hypo': {128: 8.695652173913043}, 'hyper': {128: 0.0}, 'lgbi': {128: 8.679955}, 'hgbi': {128: 2.1066213}, 'ri': {128: 10.786575}, 'sev_hyper': {128: 0.0}}
