# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training, plot_planning_training
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2, plot_testing_average_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue, maroon, navyblue = '#483D8B', '#800000', '#000080'
darkgreen =  '#006400'

exp1 = ExperimentVisualise(id='nov3_large_gamma', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='nov3_normal', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='nov3_large_gamma_zeroPenalty', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='nov3_normal_zeroPenalty', version=1.1, plot_version=1, test_seeds=5000)

exp5 = ExperimentVisualise(id='nov4_normRew_ShorterH_noStop_v2_lr1_sigmoid', version=1.1, plot_version=1, test_seeds=5000)
#exp6 = ExperimentVisualise(id='nov4_normRew_ShorterH_noStop_v2_lr3', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='nov4_normRew_ShorterH_noStop_v2_lr3_sigmaClamped', version=1.1, plot_version=1, test_seeds=5000)
exp8 = ExperimentVisualise(id='nov4_normRew_LH_noStop', version=1.1, plot_version=1, test_seeds=5000)
exp9 = ExperimentVisualise(id='nov4_normRew_LH_noStop_v2', version=1.1, plot_version=1, test_seeds=5000)
exp10 = ExperimentVisualise(id='nov4_normRew_LongerH_noStop_v2', version=1.1, plot_version=1, test_seeds=5000)

exp11 = ExperimentVisualise(id='nov4_1Penalty_short_rewNormOFF', version=1.1, plot_version=1, test_seeds=5000)


exp12 = ExperimentVisualise(id='nov5_entropy0_clipsigma_66_hardRew_MA_singleTrainer', version=1.1, plot_version=1, test_seeds=5000)
exp13 = ExperimentVisualise(id='nov5_entropy0_clipsigma_66_hardRew_MA', version=1.1, plot_version=1, test_seeds=5000)

exp14 = ExperimentVisualise(id='nov4_100Penalty_long', version=1.1, plot_version=1, test_seeds=5000)
exp15 = ExperimentVisualise(id='nov5_MUtesting', version=1.1, plot_version=1, test_seeds=5000)
exp16 = ExperimentVisualise(id='nov5_entropy0', version=1.1, plot_version=1, test_seeds=5000)
exp17 = ExperimentVisualise(id='nov5_entropy0_fixedsigma', version=1.1, plot_version=1, test_seeds=5000)
exp18 = ExperimentVisualise(id='nov5_entropy0_clipsigma', version=1.1, plot_version=1, test_seeds=5000)

exp19 = ExperimentVisualise(id='nov5_entropy0_clipsigma_33_hardRew', version=1.1, plot_version=1, test_seeds=5000)
exp20 = ExperimentVisualise(id='nov5_entropy0_clipsigma_66_hardRew', version=1.1, plot_version=1, test_seeds=5000)

# plot the graphs
dis_len = 2 * 1000000
command = []
disp_arr = display_commands_v2(command)
exp_vis = {
#            '1':{ "id":exp1, "color":darkgreen,"show": disp_arr[1], "label":''}, 
#            '2':{ "id":exp2, "color":maroon,"show": disp_arr[2], "label":''},  
#             '3':{ "id":exp3, "color":'r',"show": disp_arr[3], "label":''}, 
#             '4':{ "id":exp4, "color":'b',"show": disp_arr[4], "label":''},  
    
#             '5':{ "id":exp5, "color":'r',"show": disp_arr[5], "label":''}, 
#             #'6':{ "id":exp6, "color":'b',"show": disp_arr[6], "label":''},  
#              '7':{ "id":exp7, "color":'m',"show": disp_arr[7], "label":''},  
#             '8':{ "id":exp8, "color":'k',"show": disp_arr[8], "label":''},  
#              '9':{ "id":exp9, "color":'g',"show": disp_arr[9], "label":''},  
#             '10':{ "id":exp10, "color":brown,"show": disp_arr[10], "label":''},
     #'11':{ "id":exp11, "color":brown,"show": disp_arr[11], "label":''},
#
    
    '12':{ "id":exp12, "color":darkslateblue,"show": disp_arr[12], "label":''},
    
      '13':{ "id":exp13, "color":'r',"show": disp_arr[13], "label":''},
    
    
#     '14':{ "id":exp14, "color":'g',"show": disp_arr[14], "label":''},
#     '15':{ "id":exp15, "color":'k',"show": disp_arr[15], "label":''},
#     '16':{ "id":exp16, "color":'b',"show": disp_arr[16], "label":''},
   
    
    
    # '17':{ "id":exp17, "color":'r',"show": disp_arr[17], "label":''},
    # '18':{ "id":exp18, "color":'m',"show": disp_arr[18], "label":''},
    '19':{ "id":exp19, "color":'g', "show": disp_arr[19], "label":''},
     '20':{ "id":exp20, "color":maroon,"show": disp_arr[20], "label":''},
                  }

#groups = [['3', '7','10', '11'], ['12', '13','14']]
#plot_testing_average_metric(exp_vis, groups, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)


plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True, label=False)  # normal
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=70, fill=False)  # normal
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)

# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='aBGP_rmse', goal=5, fill=False)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='cBGP_rmse', goal=5, fill=False)
# plot_aux_training(exp_vis, 500, 1)
# plot_planning_training(exp_vis, 500, 1)

# %%
# debugging a given experimentset_args
target_exp = exp13
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {140: 142}, 't': {140: 312}, 'reward': {140: 241.7829}, 'normo': {140: 74.67948717948718}, 'hypo': {140: 2.243589743589744}, 'sev_hypo': {140: 0.0}, 'hyper': {140: 23.07692307692308}, 'lgbi': {140: 2.8875952}, 'hgbi': {140: 6.5397315}, 'ri': {140: 9.427326}, 'sev_hyper': {140: 0.0}, 'aBGP_rmse': {140: 186.45096}, 'cBGP_rmse': {140: 183.6493}}
# {'epi': {140: 142}, 't': {140: 312}, 'reward': {140: 208.68471}, 'normo': {140: 61.85897435897436}, 'hypo': {140: 0.0}, 'sev_hypo': {140: 0.0}, 'hyper': {140: 38.14102564102564}, 'lgbi': {140: 1.5543865}, 'hgbi': {140: 8.498415}, 'ri': {140: 10.052801}, 'sev_hyper': {140: 0.0}, 'aBGP_rmse': {140: 156.98155}, 'cBGP_rmse': {140: 154.23236}}
# ...
