# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'

exp1 = ExperimentVisualise(id='sep27_5_48hr__16hid_LH_ins1', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='sep27_5_36hr__16hid_LH_ins1', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='sep27_5_24hr_16hid_LH_ins1', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='sep27_5_24hr_16hid_LH_ins1_addfeatures7', version=1.1, plot_version=1, test_seeds=5000)
exp5 = ExperimentVisualise(id='sep27_5_48hr_32hid_LH_ins1_addfeatures7', version=1.1, plot_version=1, test_seeds=5000)
exp6 = ExperimentVisualise(id='sep27_5_LH_24hr_16lstm_LB2048', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='sep27_5_LH_VLbatch', version=1.1, plot_version=1, test_seeds=5000)
exp8 = ExperimentVisualise(id='sep27_5_normrew_2048', version=1.1, plot_version=1, test_seeds=5000)
exp9 = ExperimentVisualise(id='sep27_5_normrew_2048_ppo', version=1.1, plot_version=1, test_seeds=5000)
exp10 = ExperimentVisualise(id='sep27_5_normrew_2048', version=1.1, plot_version=1, test_seeds=5000)
exp11 = ExperimentVisualise(id='sep27_5_normrew_2048_ppo', version=1.1, plot_version=1, test_seeds=5000)


command = ['off r g m b k']  #

#command = []  
dis_len = 5 * 1000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
            '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
            '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
            '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
            '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
              '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
              '7':{ "id":exp7,"color":brown,"show": disp_arr[6]},
              '8':{ "id":exp8,"color":pink,"show": disp_arr[7]},
            '9':{ "id":exp9,"color":'g',"show": disp_arr[7]},
#           '10':{ "id":exp10,"color":orange,"show": disp_arr[7]},
#            '11':{ "id":exp11,"color":'r',"show": disp_arr[7]},
#                 '12':{ "id":exp12,"color":'k',"show": disp_arr[7]},
#              '13':{ "id":exp13,"color":'b',"show": disp_arr[7]},
#      '14':{ "id":exp14,"color":'m',"show": disp_arr[7]},
          }

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 10)

# %%
#debugging a given experimentset_args
target_exp = exp9
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 294.20398}, 'normo': {132: 75.32051282051282}, 'hypo': {132: 6.089743589743589}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 17.307692307692307}, 'lgbi': {132: 3.7801974}, 'hgbi': {132: 7.6030073}, 'ri': {132: 11.383204}, 'sev_hyper': {132: 1.2820512820512822}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 259.28485}, 'normo': {132: 53.20512820512821}, 'hypo': {132: 0.0}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 25.96153846153846}, 'lgbi': {132: 0.23996037}, 'hgbi': {132: 20.07448}, 'ri': {132: 20.31444}, 'sev_hyper': {132: 20.83333333333333}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 265.7366}, 'normo': {132: 51.6025641025641}, 'hypo': {132: 0.3205128205128205}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 32.05128205128205}, 'lgbi': {132: 2.3540702}, 'hgbi': {132: 18.915207}, 'ri': {132: 21.269278}, 'sev_hyper': {132: 16.025641025641026}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 275.71664}, 'normo': {132: 57.37179487179487}, 'hypo': {132: 12.5}, 'sev_hypo': {132: 0.9615384615384616}, 'hyper': {132: 17.94871794871795}, 'lgbi': {132: 7.923556}, 'hgbi': {132: 13.276265}, 'ri': {132: 21.199821}, 'sev_hyper': {132: 11.217948717948715}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 272.81537}, 'normo': {132: 63.14102564102564}, 'hypo': {132: 5.448717948717949}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 16.346153846153847}, 'lgbi': {132: 3.511676}, 'hgbi': {132: 18.526667}, 'ri': {132: 22.038343}, 'sev_hyper': {132: 15.064102564102564}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 262.5602}, 'normo': {132: 55.76923076923077}, 'hypo': {132: 7.371794871794871}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 18.58974358974359}, 'lgbi': {132: 3.6348207}, 'hgbi': {132: 22.219769}, 'ri': {132: 25.85459}, 'sev_hyper': {132: 18.26923076923077}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 277.69666}, 'normo': {132: 69.23076923076923}, 'hypo': {132: 0.0}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 16.346153846153847}, 'lgbi': {132: 1.0818418}, 'hgbi': {132: 17.190155}, 'ri': {132: 18.271997}, 'sev_hyper': {132: 14.423076923076923}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 276.91583}, 'normo': {132: 60.256410256410255}, 'hypo': {132: 5.128205128205129}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 22.115384615384617}, 'lgbi': {132: 3.8173459}, 'hgbi': {132: 13.89302}, 'ri': {132: 17.710365}, 'sev_hyper': {132: 12.5}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 258.9301}, 'normo': {132: 53.84615384615385}, 'hypo': {132: 0.0}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 26.602564102564106}, 'lgbi': {132: 1.0862464}, 'hgbi': {132: 21.03837}, 'ri': {132: 22.124617}, 'sev_hyper': {132: 19.55128205128205}}
# {'epi': {132: 134}, 't': {132: 312}, 'reward': {132: 293.2563}, 'normo': {132: 79.48717948717949}, 'hypo': {132: 4.487179487179487}, 'sev_hypo': {132: 0.0}, 'hyper': {132: 10.897435897435898}, 'lgbi': {132: 3.2694097}, 'hgbi': {132: 7.83794}, 'ri': {132: 11.107349}, 'sev_hyper': {132: 5.128205128205129}}

# %%
from utils.reward_func_explore import plot_reward
plot_reward(rew_func=['original','severe_aggressive', 'smooth_aggressive'], color=['r', 'g', 'b'], guidelines=False)
