# %%
import os
import sys
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
import pandas as pd
import numpy as np
import json
    
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='july6_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='july6_1', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='july6_2', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='july6_3', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='july6_4', version=1.1, plot_version=1)
#exp6 = ExperimentVisualise(id='july5_5', version=1.1, plot_version=1)
# exp7 = ExperimentVisualise(id='july2_0', version=1.1, plot_version=1)
# exp8 = ExperimentVisualise(id='july2_0', version=1.1, plot_version=1)
# exp9 = ExperimentVisualise(id='j25_8', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='j25_9', version=1.1, plot_version=1)

command = []
dis_len = 3000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
#           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
#            '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
#            '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
#            '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#            '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)

# %%
# debugging a given experimentset_args
target_exp = exp4
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {83: 168}, 't': {83: 312}, 'reward': {83: 219.65207}, 'normo': {83: 54.48717948717949}, 'hypo': {83: 1.2820512820512822}, 'sev_hypo': {83: 0.0}, 'hyper': {83: 19.871794871794872}, 'lgbi': {83: 1.8334314}, 'hgbi': {83: 20.88292}, 'ri': {83: 22.71635}, 'sev_hyper': {83: 24.35897435897436}}
# {'epi': {83: 168}, 't': {83: 312}, 'reward': {83: 207.61716}, 'normo': {83: 42.30769230769231}, 'hypo': {83: 0.0}, 'sev_hypo': {83: 0.0}, 'hyper': {83: 32.37179487179487}, 'lgbi': {83: 0.35841483}, 'hgbi': {83: 25.120468}, 'ri': {83: 25.478884}, 'sev_hyper': {83: 25.32051282051282}}
# {'epi': {83: 168}, 't': {83: 312}, 'reward': {83: 224.7323}, 'normo': {83: 41.98717948717949}, 'hypo': {83: 0.0}, 'sev_hypo': {83: 0.0}, 'hyper': {83: 37.5}, 'lgbi': {83: 0.30104882}, 'hgbi': {83: 19.64308}, 'ri': {83: 19.944128}, 'sev_hyper': {83: 20.512820512820515}}
# {'epi': {83: 168}, 't': {83: 312}, 'reward': {83: 197.75409}, 'normo': {83: 26.923076923076923}, 'hypo': {83: 14.743589743589745}, 'sev_hypo': {83: 3.525641025641025}, 'hyper': {83: 31.73076923076923}, 'lgbi': {83: 10.747981}, 'hgbi': {83: 26.656084}, 'ri': {83: 37.404064}, 'sev_hyper': {83: 23.07692307692308}}
# {'epi': {83: 168}, 't': {83: 312}, 'reward': {83: 188.59328}, 'normo': {83: 36.21794871794872}, 'hypo': {83: 0.0}, 'sev_hypo': {83: 0.0}, 'hyper': {83: 31.08974358974359}, 'lgbi': {83: 0.22029252}, 'hgbi': {83: 24.750162}, 'ri': {83: 24.970455}, 'sev_hyper': {83: 32.69230769230769}}
