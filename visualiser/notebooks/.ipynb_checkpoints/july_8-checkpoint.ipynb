# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='july8_negrew_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='july8_negrew_2', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='july8_negrew_3', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='july8_negrew_2_ppo', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='july8_negrew_3_ppo', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='july8_2_sparse_ppo', version=1.1, plot_version=1)
exp7 = ExperimentVisualise(id='july8_3_sparse_ppo', version=1.1, plot_version=1)
exp8 = ExperimentVisualise(id='july8_2_sparse_ppo_aux', version=1.1, plot_version=1)
exp9 = ExperimentVisualise(id='july8_3_sparse_ppo_aux', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='j25_9', version=1.1, plot_version=1)

command = []
#command = ['off c lime brown orange']
dis_len = 5000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
            '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
            '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
            '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#            '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)

# %%
# debugging a given experimentset_args
target_exp = exp3
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {90: 182}, 't': {90: 220}, 'reward': {90: 148.17996}, 'normo': {90: 31.818181818181817}, 'hypo': {90: 11.818181818181818}, 'sev_hypo': {90: 1.818181818181818}, 'hyper': {90: 46.36363636363637}, 'lgbi': {90: 9.459252}, 'hgbi': {90: 19.030333}, 'ri': {90: 28.489586}, 'sev_hyper': {90: 8.181818181818182}}
# {'epi': {90: 182}, 't': {90: 87}, 'reward': {90: 65.575035}, 'normo': {90: 41.37931034482759}, 'hypo': {90: 14.942528735632184}, 'sev_hypo': {90: 8.045977011494253}, 'hyper': {90: 35.632183908045974}, 'lgbi': {90: 12.528658}, 'hgbi': {90: 9.959016}, 'ri': {90: 22.487675}, 'sev_hyper': {90: 0.0}}
# {'epi': {90: 182}, 't': {90: 195}, 'reward': {90: 145.73418}, 'normo': {90: 42.56410256410256}, 'hypo': {90: 13.846153846153848}, 'sev_hypo': {90: 1.5384615384615383}, 'hyper': {90: 36.92307692307692}, 'lgbi': {90: 8.521886}, 'hgbi': {90: 17.548492}, 'ri': {90: 26.070377}, 'sev_hyper': {90: 5.128205128205129}}
# {'epi': {90: 182}, 't': {90: 171}, 'reward': {90: 116.17921}, 'normo': {90: 50.87719298245614}, 'hypo': {90: 15.2046783625731}, 'sev_hypo': {90: 12.865497076023392}, 'hyper': {90: 21.05263157894737}, 'lgbi': {90: 13.3841715}, 'hgbi': {90: 7.054777}, 'ri': {90: 20.43895}, 'sev_hyper': {90: 0.0}}
# {'epi': {90: 182}, 't': {90: 249}, 'reward': {90: 195.2575}, 'normo': {90: 53.01204819277108}, 'hypo': {90: 12.449799196787149}, 'sev_hypo': {90: 2.0080321285140563}, 'hyper': {90: 28.11244979919679}, 'lgbi': {90: 8.523094}, 'hgbi': {90: 12.165826}, 'ri': {90: 20.68892}, 'sev_hyper': {90: 4.417670682730924}}
