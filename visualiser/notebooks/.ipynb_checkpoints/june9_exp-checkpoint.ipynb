# %%
import os
import sys
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j9_multi_n_steps_id0', version=1.1, plot_version=0)
exp2 = ExperimentVisualise(id='j9_multi_n_steps_id1', version=1.1, plot_version=0)
exp3 = ExperimentVisualise(id='j9_multi_n_steps_id2', version=1.1, plot_version=0)
exp4 = ExperimentVisualise(id='j9_multi_n_steps_id3', version=1.1, plot_version=0)
exp5 = ExperimentVisualise(id='j9_multi_n_steps_id4', version=1.1, plot_version=0)
exp6 = ExperimentVisualise(id='j9_multi_n_steps_id5', version=1.1, plot_version=0)

#Note: In this version the gamma and lambda are old, meal history given. but tod not given

exp_vis = {'1':{"id":exp1, "color":'r',"show": True}, 
           '2':{"id":exp2, "color":'g',"show": True},  
           '3':{"id":exp3, "color":'b',"show": True},
           '4':{"id":exp4, "color":'m',"show": True},
           '5':{"id":exp5, "color":'k',"show": True},
           '6':{"id":exp6, "color":'c',"show": True}
           }

# plot the graphs
dis_len = 3000000
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 2000, 50)

# %%
# debugging a given experimentset_args
target_exp = exp6
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=288)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {500: 1002}, 't': {500: 288}, 'reward': {500: 280.252}, 'normo': {500: 90.27777777777776}, 'hypo': {500: 1.3888888888888888}, 'sev_hypo': {500: 0.0}, 'hyper': {500: 8.333333333333334}, 'lgbi': {500: 1.7583901}, 'hgbi': {500: 4.2206326}, 'ri': {500: 5.9790225}}
# {'epi': {500: 1002}, 't': {500: 288}, 'reward': {500: 277.59467}, 'normo': {500: 84.72222222222223}, 'hypo': {500: 1.3888888888888888}, 'sev_hypo': {500: 0.0}, 'hyper': {500: 13.88888888888889}, 'lgbi': {500: 1.9454485}, 'hgbi': {500: 5.327443}, 'ri': {500: 7.2728915}}
# {'epi': {500: 1002}, 't': {500: 288}, 'reward': {500: 282.7462}, 'normo': {500: 95.48611111111111}, 'hypo': {500: 0.0}, 'sev_hypo': {500: 0.0}, 'hyper': {500: 4.513888888888889}, 'lgbi': {500: 1.0180146}, 'hgbi': {500: 2.9212513}, 'ri': {500: 3.9392657}}
# {'epi': {500: 1002}, 't': {500: 288}, 'reward': {500: 277.48022}, 'normo': {500: 81.59722222222223}, 'hypo': {500: 1.3888888888888888}, 'sev_hypo': {500: 0.0}, 'hyper': {500: 17.01388888888889}, 'lgbi': {500: 1.0972311}, 'hgbi': {500: 5.3761597}, 'ri': {500: 6.4733906}}
# {'epi': {500: 1002}, 't': {500: 288}, 'reward': {500: 279.1473}, 'normo': {500: 86.11111111111111}, 'hypo': {500: 5.208333333333333}, 'sev_hypo': {500: 0.0}, 'hyper': {500: 8.680555555555555}, 'lgbi': {500: 2.2684736}, 'hgbi': {500: 3.913505}, 'ri': {500: 6.1819787}}
