# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'

exp1 = ExperimentVisualise(id='sep21_2_SH_simple_rew_largeNetwork', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='sep21_2_simple_rew', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='sep21_2_SH_simple_rew', version=1.1, plot_version=1)

exp3 = ExperimentVisualise(id='sep22_2_SH_simple_rew_v1', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='sep22_2_SH_simple_rew_v2', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='sep22_2_SH_nstep32', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='sep22_2_SH_nstep16', version=1.1, plot_version=1, test_seeds=5000)

exp8 = ExperimentVisualise(id='sep22_2_SH_nstep32_stdG', version=1.1, plot_version=1, test_seeds=5000)
exp9 = ExperimentVisualise(id='sep22_2_SH_nstep16_stdG', version=1.1, plot_version=1, test_seeds=5000)

#september 21
#exp3 = ExperimentVisualise(id='sep21_2_hyper_exit', version=1.1, plot_version=1)
#exp5 = ExperimentVisualise(id='sep21_2_SH_neg_rew', version=1.1, plot_version=1)

# september 20th
# exp1 = ExperimentVisualise(id='sep20_2_dual_penalty', version=1.1, plot_version=1)
# exp2 = ExperimentVisualise(id='sep20_2_dual_penalty_ins4', version=1.1, plot_version=1)

#september 14
# exp1 = ExperimentVisualise(id='sep15_2_invertrew', version=1.1, plot_version=1)
# exp2 = ExperimentVisualise(id='sep15_2_invertrew_ppo', version=1.1, plot_version=1)
# exp3 = ExperimentVisualise(id='sep16_2_lowgammalambda_negrew', version=1.1, plot_version=1)
# exp4 = ExperimentVisualise(id='sep15_2_invertrew_aggressive_ppo', version=1.1, plot_version=1)

# exp5 = ExperimentVisualise(id='sep2_15_ins4', version=1.1, plot_version=1)
# exp6 = ExperimentVisualise(id='sep2_15_ins4_nstep256', version=1.1, plot_version=1)
# exp7 = ExperimentVisualise(id='sep2_15_ins2_vflr_3', version=1.1, plot_version=1)
# exp8 = ExperimentVisualise(id='sep2_15_ins5', version=1.1, plot_version=1)


command = ['off r']  #
dis_len = 3 * 1000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
            '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
              '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
             '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
              '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
             '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
             '7':{ "id":exp7,"color":brown,"show": disp_arr[6]},
             '8':{ "id":exp8,"color":pink,"show": disp_arr[7]},
           '9':{ "id":exp9,"color":'r',"show": disp_arr[7]},
          }

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=300, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 10)

# %%
#debugging a given experimentset_args
target_exp = exp3
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {35: 37}, 't': {35: 44}, 'reward': {35: 40.010292}, 'normo': {35: 70.45454545454545}, 'hypo': {35: 18.181818181818183}, 'sev_hypo': {35: 11.363636363636363}, 'hyper': {35: 0.0}, 'lgbi': {35: 12.462257}, 'hgbi': {35: 1.3482383}, 'ri': {35: 13.810495}, 'sev_hyper': {35: 0.0}}
# {'epi': {35: 37}, 't': {35: 51}, 'reward': {35: 48.53132}, 'normo': {35: 92.15686274509804}, 'hypo': {35: 3.92156862745098}, 'sev_hypo': {35: 3.92156862745098}, 'hyper': {35: 0.0}, 'lgbi': {35: 7.9790645}, 'hgbi': {35: 1.640147}, 'ri': {35: 9.619211}, 'sev_hyper': {35: 0.0}}
