# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j10_multi_n_steps_id0', version=1.1)
exp2 = ExperimentVisualise(id='j10_multi_n_steps_id1', version=1.1)
exp3 = ExperimentVisualise(id='j10_multi_n_steps_id2', version=1.1)
exp4 = ExperimentVisualise(id='j10_multi_n_steps_id3', version=1.1)
exp5 = ExperimentVisualise(id='j10_multi_n_steps_id4', version=1.1)
exp6 = ExperimentVisualise(id='j10_multi_n_steps_id5', version=1.1)

# False, True
# exp4

#note/; in this version only the meal history is removed. the gamma, lambda i snew and has tod as feature.

exp_vis = {'1':{
                "id":exp1,
                "color":'r',
                "show": True}, 
           '2':{
                "id":exp2,
                "color":'g',
                "show": True},  
           '3':{
                "id":exp3,
                "color":'b',
                "show": True},
           '4':{
                "id":exp4,
                "color":'m',
                "show": True},
           '5':{
                "id":exp5,
                "color":'k',
                "show": True},
           '6':{
                "id":exp6,
                "color":'c',
                "show": True}
           }

# plot the graphs
dis_len = 5000000
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp3
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 466
plot_episode(target_exp, tester=0, episode=target_epi)
plot_episode(target_exp, tester=1, episode=target_epi)
plot_episode(target_exp, tester=2, episode=target_epi)
plot_episode(target_exp, tester=3, episode=target_epi)
plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {233: 468}, 't': {233: 288}, 'reward': {233: 250.00269}, 'normo': {233: 53.47222222222222}, 'hypo': {233: 0.0}, 'sev_hypo': {233: 0.0}, 'hyper': {233: 46.52777777777778}, 'lgbi': {233: 2.771185}, 'hgbi': {233: 13.646651}, 'ri': {233: 16.417835}}
# {'epi': {233: 468}, 't': {233: 288}, 'reward': {233: 250.56624}, 'normo': {233: 45.48611111111112}, 'hypo': {233: 0.0}, 'sev_hypo': {233: 0.0}, 'hyper': {233: 54.513888888888886}, 'lgbi': {233: 0.0021998903}, 'hgbi': {233: 13.043113}, 'ri': {233: 13.045313}}
# {'epi': {233: 468}, 't': {233: 288}, 'reward': {233: 233.31943}, 'normo': {233: 50.69444444444444}, 'hypo': {233: 8.680555555555555}, 'sev_hypo': {233: 0.0}, 'hyper': {233: 40.625}, 'lgbi': {233: 6.3711452}, 'hgbi': {233: 22.51855}, 'ri': {233: 28.889696}}
# {'epi': {232: 466}, 't': {232: 288}, 'reward': {232: 249.42508}, 'normo': {232: 54.513888888888886}, 'hypo': {232: 0.3472222222222222}, 'sev_hypo': {232: 0.0}, 'hyper': {232: 45.138888888888886}, 'lgbi': {232: 1.8159169}, 'hgbi': {232: 14.591806}, 'ri': {232: 16.407722}}
# {'epi': {232: 466}, 't': {232: 288}, 'reward': {232: 239.72644}, 'normo': {232: 34.02777777777778}, 'hypo': {232: 17.708333333333332}, 'sev_hypo': {232: 1.3888888888888888}, 'hyper': {232: 48.263888888888886}, 'lgbi': {232: 10.5770855}, 'hgbi': {232: 19.140327}, 'ri': {232: 29.717413}}
