# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training, plot_planning_training
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2, plot_testing_average_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue, maroon, navyblue = '#483D8B', '#800000', '#000080'
darkgreen =  '#006400'

exp1 = ExperimentVisualise(id='nov10_differentialRew_avgRew_adult2', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='nov10_differentialRew_avgRew_adult3', version=1.1, plot_version=1, test_seeds=5000)
# exp3 = ExperimentVisualise(id='nov9_rewNew', version=1.1, plot_version=1, test_seeds=5000)
# exp4 = ExperimentVisualise(id='nov9_fullNeg_rewNew', version=1.1, plot_version=1, test_seeds=5000)
# exp5 = ExperimentVisualise(id='nov9_smooth_severe', version=1.1, plot_version=1, test_seeds=5000)
# exp6 = ExperimentVisualise(id='nov9_smooth_severe_decay2_worker16', version=1.1, plot_version=1, test_seeds=5000)
# exp7 = ExperimentVisualise(id='nov9_shiftedRew_decay2_worker32', version=1.1, plot_version=1, test_seeds=5000)

exp8 = ExperimentVisualise(id='nov10_differentialRew_discountRew', version=1.1, plot_version=1, test_seeds=5000)
exp9 = ExperimentVisualise(id='nov10_differentialRew_avgRew', version=1.1, plot_version=1, test_seeds=5000)
exp10 = ExperimentVisualise(id='nov10_proper_avg_rew_gamma1_lambda1_avgRewCalcNEW_noStop', version=1.1, plot_version=1, test_seeds=5000)
exp11 = ExperimentVisualise(id='nov10_proper_avg_rew_gamma1_lambda1_avgRewCalcNEW', version=1.1, plot_version=1, test_seeds=5000)
exp12 = ExperimentVisualise(id='nov10_proper_avg_rew_gamma1_lambda90', version=1.1, plot_version=1, test_seeds=5000)
exp13 = ExperimentVisualise(id='nov10_proper_avg_rew_gamma1_lambda1', version=1.1, plot_version=1, test_seeds=5000)

# plot the graphs
dis_len = 3 * 1000000
command = []
#command = ['only 9']
disp_arr = display_commands_v2(command)
exp_vis = {
             '1':{ "id":exp1, "color":darkgreen,"show": disp_arr[1], "label":''}, 
             '2':{ "id":exp2, "color":maroon,"show": disp_arr[2], "label":''},  
         #   '3':{ "id":exp3, "color":'r',"show": disp_arr[3], "label":''}, 
#             '4':{ "id":exp4, "color":'b',"show": disp_arr[4], "label":''},  
             # '5':{ "id":exp5, "color":'k',"show": disp_arr[5], "label":''}, 
             
            # '7':{ "id":exp7, "color":'g',"show": disp_arr[7], "label":''}, 
    
      #'6':{ "id":exp6, "color":'m',"show": disp_arr[6], "label":''}, 

        '8':{ "id":exp8, "color":'b',"show": disp_arr[8], "label":''},
          '9':{ "id":exp9, "color":'k',"show": disp_arr[9], "label":''},
          #'10':{ "id":exp10, "color":'r',"show": disp_arr[10], "label":''},
#      '11':{ "id":exp11, "color":darkgreen,"show": disp_arr[11], "label":''},
       '12':{ "id":exp12, "color":navyblue,"show": disp_arr[12], "label":''},
      '13':{ "id":exp13, "color":maroon,"show": disp_arr[13], "label":''},
     
}
#groups = [['3', '7','10', '11'], ['12', '13','14']]
#plot_testing_average_metric(exp_vis, groups, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)


plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True, label=False)  # normal

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=70, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=3)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='aBGP_rmse', goal=5, fill=False)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='cBGP_rmse', goal=5, fill=False)
# plot_aux_training(exp_vis, 500, 1)

# plot_planning_training(exp_vis, 500, 1)

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=256)
# Out:
#  Experiment summary...
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 130.52718}, 'normo': {504: 46.47435897435897}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 53.52564102564103}, 'lgbi': {504: 0.0}, 'hgbi': {504: 11.245183}, 'ri': {504: 11.245183}, 'sev_hyper': {504: 0.0}, 'aBGP_rmse': {504: 158.24637}, 'cBGP_rmse': {504: 158.3567}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 170.35892}, 'normo': {504: 64.42307692307692}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 32.37179487179487}, 'lgbi': {504: 0.25602695}, 'hgbi': {504: 9.569038}, 'ri': {504: 9.825066}, 'sev_hyper': {504: 3.2051282051282053}, 'aBGP_rmse': {504: 177.38074}, 'cBGP_rmse': {504: 177.34314}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 141.25659}, 'normo': {504: 52.56410256410256}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 41.66666666666666}, 'lgbi': {504: 0.0}, 'hgbi': {504: 11.627082}, 'ri': {504: 11.627082}, 'sev_hyper': {504: 5.769230769230769}, 'aBGP_rmse': {504: 161.20953}, 'cBGP_rmse': {504: 161.25566}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 162.84473}, 'normo': {504: 59.61538461538461}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 40.38461538461539}, 'lgbi': {504: 0.08929141}, 'hgbi': {504: 9.690196}, 'ri': {504: 9.779488}, 'sev_hyper': {504: 0.0}, 'aBGP_rmse': {504: 172.0505}, 'cBGP_rmse': {504: 172.05789}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 169.8295}, 'normo': {504: 62.17948717948718}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 37.82051282051282}, 'lgbi': {504: 0.0767802}, 'hgbi': {504: 8.151608}, 'ri': {504: 8.228389}, 'sev_hyper': {504: 0.0}, 'aBGP_rmse': {504: 175.34686}, 'cBGP_rmse': {504: 175.34795}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 129.93826}, 'normo': {504: 41.66666666666666}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 53.84615384615385}, 'lgbi': {504: 0.03505416}, 'hgbi': {504: 12.828865}, 'ri': {504: 12.863919}, 'sev_hyper': {504: 4.487179487179487}, 'aBGP_rmse': {504: 157.39325}, 'cBGP_rmse': {504: 157.46252}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 200.0803}, 'normo': {504: 72.11538461538461}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 27.884615384615383}, 'lgbi': {504: 0.009690311}, 'hgbi': {504: 6.344956}, 'ri': {504: 6.354646}, 'sev_hyper': {504: 0.0}, 'aBGP_rmse': {504: 185.90598}, 'cBGP_rmse': {504: 185.83731}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 136.96579}, 'normo': {504: 49.35897435897436}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 44.23076923076923}, 'lgbi': {504: 0.0}, 'hgbi': {504: 11.999763}, 'ri': {504: 11.999763}, 'sev_hyper': {504: 6.410256410256411}, 'aBGP_rmse': {504: 159.15906}, 'cBGP_rmse': {504: 159.19798}}
# {'epi': {504: 506}, 't': {504: 312}, 'reward': {504: 103.19601}, 'normo': {504: 33.97435897435897}, 'hypo': {504: 0.0}, 'sev_hypo': {504: 0.0}, 'hyper': {504: 48.07692307692308}, 'lgbi': {504: 0.04894587}, 'hgbi': {504: 17.489647}, 'ri': {504: 17.538593}, 'sev_hyper': {504: 17.94871794871795}, 'aBGP_rmse': {504: 141.1335}, 'cBGP_rmse': {504: 141.20415}}
# {'epi': {503: 505}, 't': {503: 312}, 'reward': {503: 206.68076}, 'normo': {503: 76.28205128205128}, 'hypo': {503: 0.0}, 'sev_hypo': {503: 0.0}, 'hyper': {503: 20.83333333333333}, 'lgbi': {503: 0.05670279}, 'hgbi': {503: 6.8702035}, 'ri': {503: 6.926906}, 'sev_hyper': {503: 2.8846153846153846}, 'aBGP_rmse': {503: 188.40575}, 'cBGP_rmse': {503: 188.36877}}
