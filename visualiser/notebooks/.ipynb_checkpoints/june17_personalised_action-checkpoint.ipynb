# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j17_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='j17_1', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='j17_2', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='j17_3', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='j17_4', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='j17_5', version=1.1, plot_version=1)

command = ['only k c']
dis_len = 5000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]} }
plot_testing_metric(exp_vis, 'min_max', dis_len, 'reward', 288, fill=True)  # min_max, normal
# plot_testing_metric(exp_vis, 'min_max', dis_len, 'normo', 75, fill=False)  # min_max, normal
# plot_testing_metric(exp_vis, 'min_max', dis_len, 'ri', 5, fill=False)
# plot_training_logs(exp_vis, dis_len, version=2)
# plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp6
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 504
plot_episode(target_exp, tester=0, episode=target_epi)
# plot_episode(target_exp, tester=1, episode=target_epi)
# plot_episode(target_exp, tester=2, episode=target_epi)
# plot_episode(target_exp, tester=3, episode=target_epi)
# plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {932: 1866}, 't': {932: 288}, 'reward': {932: 232.8399}, 'normo': {932: 53.81944444444444}, 'hypo': {932: 14.23611111111111}, 'sev_hypo': {932: 0.0}, 'hyper': {932: 20.13888888888889}, 'lgbi': {932: 6.230116}, 'hgbi': {932: 18.733868}, 'ri': {932: 24.963984}, 'sev_hyper': {932: 11.805555555555555}}
# {'epi': {932: 1866}, 't': {932: 288}, 'reward': {932: 206.7015}, 'normo': {932: 41.66666666666666}, 'hypo': {932: 20.83333333333333}, 'sev_hypo': {932: 3.125}, 'hyper': {932: 16.319444444444443}, 'lgbi': {932: 9.162416}, 'hgbi': {932: 25.730986}, 'ri': {932: 34.893402}, 'sev_hyper': {932: 18.05555555555556}}
# {'epi': {932: 1866}, 't': {932: 288}, 'reward': {932: 234.03308}, 'normo': {932: 61.11111111111112}, 'hypo': {932: 5.208333333333333}, 'sev_hypo': {932: 0.0}, 'hyper': {932: 20.48611111111111}, 'lgbi': {932: 4.1744165}, 'hgbi': {932: 16.259903}, 'ri': {932: 20.434319}, 'sev_hyper': {932: 13.194444444444445}}
# ...
