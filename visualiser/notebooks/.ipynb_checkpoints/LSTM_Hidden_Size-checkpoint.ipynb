# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='mygpu_j2_lstm16_1_id2', version=1.1)
exp2 = ExperimentVisualise(id='mygpu_j2_lstm32_1_id2', version=1.1)
exp3 = ExperimentVisualise(id='mygpu_j2_lstm64_1_id2', version=1.1)
exp4 = ExperimentVisualise(id='mygpu_j2_lstm10_1_id2', version=1.1)
exp5 = ExperimentVisualise(id='mygpu_j2_lstm8_1_id2', version=1.1)
exp6 = ExperimentVisualise(id='mygpu_j2_lstm4_1_id2', version=1.1)

# False
# exp4

exp_vis = {'1':{
                "id":exp1,
                "color":'r',
                "show": True},
           '2':{
                "id":exp2,
                "color":'g',
                "show": False},
           '3':{
                "id":exp3,
                "color":'b',
                "show": False},
           '4':{
                "id":exp4,
                "color":'m',
                "show": False},
           '5':{
                "id":exp5,
                "color":'k',
                "show": False},
           '6':{
                "id":exp6,
                "color":'c',
                "show": True}
           }

# plot the graphs
dis_len = 20000000
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp2
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 232
plot_episode(target_exp, tester=0, episode=target_epi)
plot_episode(target_exp, tester=1, episode=target_epi)
plot_episode(target_exp, tester=2, episode=target_epi)
plot_episode(target_exp, tester=3, episode=target_epi)
plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {149: 300}, 't': {149: 39}, 'reward': {149: 36.10602}, 'normo': {149: 84.61538461538461}, 'hypo': {149: 15.384615384615383}, 'sev_hypo': {149: 7.6923076923076925}, 'hyper': {149: 0.0}, 'lgbi': {149: 9.480122}, 'hgbi': {149: 2.3738856}, 'ri': {149: 11.854008}}
# {'epi': {149: 300}, 't': {149: 45}, 'reward': {149: 40.6169}, 'normo': {149: 62.22222222222222}, 'hypo': {149: 17.77777777777778}, 'sev_hypo': {149: 13.333333333333334}, 'hyper': {149: 20.0}, 'lgbi': {149: 15.323506}, 'hgbi': {149: 5.2252526}, 'ri': {149: 20.54876}}
# {'epi': {149: 300}, 't': {149: 76}, 'reward': {149: 68.10304}, 'normo': {149: 52.63157894736842}, 'hypo': {149: 44.73684210526316}, 'sev_hypo': {149: 9.210526315789474}, 'hyper': {149: 2.631578947368421}, 'lgbi': {149: 11.496169}, 'hgbi': {149: 4.5528555}, 'ri': {149: 16.049025}}
# {'epi': {149: 300}, 't': {149: 70}, 'reward': {149: 62.269768}, 'normo': {149: 51.42857142857143}, 'hypo': {149: 48.57142857142857}, 'sev_hypo': {149: 15.714285714285714}, 'hyper': {149: 0.0}, 'lgbi': {149: 14.0950165}, 'hgbi': {149: 1.5756531}, 'ri': {149: 15.67067}}
# {'epi': {149: 300}, 't': {149: 71}, 'reward': {149: 68.11324}, 'normo': {149: 94.3661971830986}, 'hypo': {149: 5.633802816901408}, 'sev_hypo': {149: 2.816901408450704}, 'hyper': {149: 0.0}, 'lgbi': {149: 4.0589542}, 'hgbi': {149: 1.2722176}, 'ri': {149: 5.331172}}
