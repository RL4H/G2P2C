# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j8_multi_n_steps_id0', version=1.1)
exp2 = ExperimentVisualise(id='j8_multi_n_steps_id1', version=1.1)
exp3 = ExperimentVisualise(id='j8_multi_n_steps_id2', version=1.1)
exp4 = ExperimentVisualise(id='j8_multi_n_steps_id3', version=1.1)
exp5 = ExperimentVisualise(id='j8_multi_n_steps_id4', version=1.1)
exp6 = ExperimentVisualise(id='j8_multi_n_steps_id5', version=1.1)

# False, True
# exp4

exp_vis = {'1':{
                "id":exp1,
                "color":'r',
                "show": True}, 
           '2':{
                "id":exp2,
                "color":'g',
                "show": True},  
           '3':{
                "id":exp3,
                "color":'b',
                "show": True},
           '4':{
                "id":exp4,
                "color":'m',
                "show": True},
           '5':{
                "id":exp5,
                "color":'k',
                "show": True},
           '6':{
                "id":exp6,
                "color":'c',
                "show": True}
           }

# plot the graphs
dis_len = 10000000
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp3
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 142
plot_episode(target_exp, tester=0, episode=target_epi)
plot_episode(target_exp, tester=1, episode=target_epi)
plot_episode(target_exp, tester=2, episode=target_epi)
plot_episode(target_exp, tester=3, episode=target_epi)
plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {493: 988}, 't': {493: 288}, 'reward': {493: 218.48344}, 'normo': {493: 31.25}, 'hypo': {493: 0.0}, 'sev_hypo': {493: 0.0}, 'hyper': {493: 68.75}, 'lgbi': {493: 0.0}, 'hgbi': {493: 24.137684}, 'ri': {493: 24.137684}}
# {'epi': {493: 988}, 't': {493: 288}, 'reward': {493: 216.94618}, 'normo': {493: 34.72222222222222}, 'hypo': {493: 0.0}, 'sev_hypo': {493: 0.0}, 'hyper': {493: 65.27777777777777}, 'lgbi': {493: 0.0}, 'hgbi': {493: 24.671457}, 'ri': {493: 24.671457}}
# {'epi': {493: 988}, 't': {493: 288}, 'reward': {493: 187.90897}, 'normo': {493: 12.84722222222222}, 'hypo': {493: 0.0}, 'sev_hypo': {493: 0.0}, 'hyper': {493: 87.15277777777777}, 'lgbi': {493: 0.0}, 'hgbi': {493: 34.753826}, 'ri': {493: 34.753826}}
# {'epi': {493: 988}, 't': {493: 288}, 'reward': {493: 222.00616}, 'normo': {493: 28.125}, 'hypo': {493: 0.0}, 'sev_hypo': {493: 0.0}, 'hyper': {493: 71.875}, 'lgbi': {493: 0.0}, 'hgbi': {493: 22.914518}, 'ri': {493: 22.914518}}
# {'epi': {493: 988}, 't': {493: 288}, 'reward': {493: 215.62646}, 'normo': {493: 34.02777777777778}, 'hypo': {493: 0.0}, 'sev_hypo': {493: 0.0}, 'hyper': {493: 65.97222222222223}, 'lgbi': {493: 0.0038901689}, 'hgbi': {493: 25.217241}, 'ri': {493: 25.221132}}
