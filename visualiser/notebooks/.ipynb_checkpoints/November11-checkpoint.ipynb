# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training, plot_planning_training
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2, plot_testing_average_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue, maroon, navyblue = '#483D8B', '#800000', '#000080'
darkgreen =  '#006400'

exp1 = ExperimentVisualise(id='nov11_avgDiffRew_mean_lrD_adult1', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='nov11_avgDiffRew_mean_lrD_adult1_simpleRew', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='nov11_discount_DiffRew_mean_lrD_adult1_simpleRew', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='nov11_avgDiffRew_mean_lrD_adult1_simpleRew_312', version=1.1, plot_version=1, test_seeds=5000)
exp5 = ExperimentVisualise(id='nov11_discountDiffRew_mean_lrD_adult1_simpleRew_312', version=1.1, plot_version=1, test_seeds=5000)


exp6 = ExperimentVisualise(id='nov11_discountDiffRew_mean_lrD_adult2_simpleRew_100', version=1.1, plot_version=1, test_seeds=5000)
exp7 = ExperimentVisualise(id='nov11_discountDiffRew_mean_lrD_adult3_simpleRew_100', version=1.1, plot_version=1, test_seeds=5000)
exp8 = ExperimentVisualise(id='nov11_discountDiffRew_mean_lrD_adult4_simpleRew_100', version=1.1, plot_version=1, test_seeds=5000)

exp9 = ExperimentVisualise(id='nov11_avg_special_uni', version=1.1, plot_version=1, test_seeds=5000)
exp10 = ExperimentVisualise(id='nov11_discount_uni', version=1.1, plot_version=1, test_seeds=5000)
exp11 = ExperimentVisualise(id='nov11_discount_special_adult2', version=1.1, plot_version=1, test_seeds=5000)
exp12 = ExperimentVisualise(id='nov11_avg_uni_adult2', version=1.1, plot_version=1, test_seeds=5000)



# plot the graphs
dis_len = 1 * 1000000
command = []
command = ['only 9 10 11 12']
disp_arr = display_commands_v2(command)
exp_vis = {
            # '1':{ "id":exp1, "color":darkgreen,"show": disp_arr[1], "label":''}, 
             '2':{ "id":exp2, "color":maroon,"show": disp_arr[2], "label":''},  
            '3':{ "id":exp3, "color":'r',"show": disp_arr[3], "label":''}, 
            #  '4':{ "id":exp4, "color":'b',"show": disp_arr[4], "label":''},  
   #           '5':{ "id":exp5, "color":'k',"show": disp_arr[5], "label":''}, 
    
            '6':{ "id":exp6, "color":'m',"show": disp_arr[6], "label":''}, 
            '7':{ "id":exp7, "color":'g',"show": disp_arr[7], "label":''}, 
            '8':{ "id":exp8, "color":navyblue,"show": disp_arr[8], "label":''},
    
            # these ar base on uniform 
    
            '9':{ "id":exp9, "color":'b',"show": disp_arr[9], "label":''}, 
            '10':{ "id":exp10, "color":'k',"show": disp_arr[10], "label":''},
    '11':{ "id":exp11, "color":'m',"show": disp_arr[11], "label":''}, 
            '12':{ "id":exp12, "color":'g',"show": disp_arr[12], "label":''},

     
}
#groups = [['3', '7','10', '11'], ['12', '13','14']]
#plot_testing_average_metric(exp_vis, groups, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)


plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True, label=False)  # normal

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=70, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=3)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='aBGP_rmse', goal=5, fill=False)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='cBGP_rmse', goal=5, fill=False)
# plot_aux_training(exp_vis, 500, 1)

# plot_planning_training(exp_vis, 500, 1)

# %%
# debugging a given experimentset_args
target_exp = exp10
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=256)
# Out:
#  Experiment summary...
# {'epi': {174: 176}, 't': {174: 312}, 'reward': {174: 288.4226}, 'normo': {174: 59.2948717948718}, 'hypo': {174: 0.0}, 'sev_hypo': {174: 0.0}, 'hyper': {174: 40.70512820512821}, 'lgbi': {174: 0.8706295}, 'hgbi': {174: 8.540123}, 'ri': {174: 9.410752}, 'sev_hyper': {174: 0.0}, 'aBGP_rmse': {174: 135.96675}, 'cBGP_rmse': {174: 149.60643}}
# {'epi': {174: 176}, 't': {174: 312}, 'reward': {174: 264.84033}, 'normo': {174: 36.21794871794872}, 'hypo': {174: 0.0}, 'sev_hypo': {174: 0.0}, 'hyper': {174: 56.08974358974359}, 'lgbi': {174: 1.2342149}, 'hgbi': {174: 15.62255}, 'ri': {174: 16.856766}, 'sev_hyper': {174: 7.6923076923076925}, 'aBGP_rmse': {174: 106.06118}, 'cBGP_rmse': {174: 118.15514}}
# {'epi': {173: 175}, 't': {173: 258}, 'reward': {173: 130.41678}, 'normo': {173: 46.51162790697674}, 'hypo': {173: 25.968992248062012}, 'sev_hypo': {173: 9.689922480620154}, 'hyper': {173: 17.829457364341085}, 'lgbi': {173: 10.84153}, 'hgbi': {173: 9.644046}, 'ri': {173: 20.485577}, 'sev_hyper': {173: 0.0}, 'aBGP_rmse': {173: 196.16652}, 'cBGP_rmse': {173: 209.72453}}
# {'epi': {173: 175}, 't': {173: 312}, 'reward': {173: 273.46658}, 'normo': {173: 53.84615384615385}, 'hypo': {173: 0.0}, 'sev_hypo': {173: 0.0}, 'hyper': {173: 35.8974358974359}, 'lgbi': {173: 1.1180832}, 'hgbi': {173: 14.59693}, 'ri': {173: 15.715013}, 'sev_hyper': {173: 10.256410256410255}, 'aBGP_rmse': {173: 133.25827}, 'cBGP_rmse': {173: 145.24016}}
