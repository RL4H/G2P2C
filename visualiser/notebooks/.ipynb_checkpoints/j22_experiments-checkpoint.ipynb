# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j22_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='j22_1', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='j22_2', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='j22_3', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='j22_4', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='j22_5', version=1.1, plot_version=1)

command = []
dis_len = 5000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]}}
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=288, fill=True)  # normal
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
# plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ad17196f9e60> in <module>
#      32 # plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
#      33 # plot_training_logs(exp_vis, dis_len, version=2)
# ---> 34 plot_aux_training(exp_vis, 300)
#
# TypeError: plot_aux_training() missing 1 required positional argument: 'ymax'

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=288)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=288)
# Out:
#  Experiment summary...
# {'epi': {362: 726}, 't': {362: 288}, 'reward': {362: 267.5504}, 'normo': {362: 67.70833333333333}, 'hypo': {362: 22.22222222222222}, 'sev_hypo': {362: 1.7361111111111112}, 'hyper': {362: 8.333333333333334}, 'lgbi': {362: 7.155698}, 'hgbi': {362: 3.8783643}, 'ri': {362: 11.034062}, 'sev_hyper': {362: 0.0}}
# {'epi': {362: 726}, 't': {362: 288}, 'reward': {362: 277.10797}, 'normo': {362: 82.98611111111111}, 'hypo': {362: 2.430555555555556}, 'sev_hypo': {362: 0.0}, 'hyper': {362: 14.583333333333334}, 'lgbi': {362: 2.0901508}, 'hgbi': {362: 4.812161}, 'ri': {362: 6.902312}, 'sev_hyper': {362: 0.0}}
# {'epi': {362: 726}, 't': {362: 288}, 'reward': {362: 280.9785}, 'normo': {362: 93.75}, 'hypo': {362: 0.6944444444444444}, 'sev_hypo': {362: 0.0}, 'hyper': {362: 5.555555555555555}, 'lgbi': {362: 2.4048748}, 'hgbi': {362: 2.4494915}, 'ri': {362: 4.8543663}, 'sev_hyper': {362: 0.0}}
# {'epi': {362: 726}, 't': {362: 288}, 'reward': {362: 283.61642}, 'normo': {362: 100.0}, 'hypo': {362: 0.0}, 'sev_hypo': {362: 0.0}, 'hyper': {362: 0.0}, 'lgbi': {362: 0.44435573}, 'hgbi': {362: 1.8551952}, 'ri': {362: 2.299551}, 'sev_hyper': {362: 0.0}}
# {'epi': {362: 726}, 't': {362: 288}, 'reward': {362: 276.52332}, 'normo': {362: 77.43055555555556}, 'hypo': {362: 0.0}, 'sev_hypo': {362: 0.0}, 'hyper': {362: 22.569444444444443}, 'lgbi': {362: 1.1372297}, 'hgbi': {362: 5.177347}, 'ri': {362: 6.314577}, 'sev_hyper': {362: 0.0}}
