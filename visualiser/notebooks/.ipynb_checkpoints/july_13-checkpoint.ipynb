# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training
from visualiser.core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
    
# initialise experiment objects
lime, brown, orange, pink = '#00FF00', '#964B00', '#FFA500', '#FF1493'
exp1 = ExperimentVisualise(id='july13_0', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='july13_1', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='july13_2', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='july13_3', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='july13_4', version=1.1, plot_version=1)
# exp6 = ExperimentVisualise(id='july9_5', version=1.1, plot_version=1)
# exp7 = ExperimentVisualise(id='july9_6', version=1.1, plot_version=1)
# exp8 = ExperimentVisualise(id='july9_7', version=1.1, plot_version=1)
# exp9 = ExperimentVisualise(id='july9_8', version=1.1, plot_version=1)
# exp10 = ExperimentVisualise(id='july9_9', version=1.1, plot_version=1)

command = []
#command = ['off c lime brown orange']
dis_len = 5000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
#            '6':{ "id":exp6,"color":'c',"show": disp_arr[5]},
#             '7':{ "id":exp7,"color": lime,"show": disp_arr[6]},  
#             '8':{ "id":exp8,"color": brown,"show": disp_arr[7]}, 
#             '9':{ "id":exp9,"color":orange,"show": disp_arr[8]},
#             '10':{ "id":exp10,"color": pink,"show": disp_arr[9]}
          }
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 5)

# %%
# debugging a given experimentset_args
target_exp = exp3
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=5000)
# Out:
#  Experiment summary...
# {'epi': {112: 226}, 't': {112: 141}, 'reward': {112: 54.238777}, 'normo': {112: 68.79432624113475}, 'hypo': {112: 2.8368794326241136}, 'sev_hypo': {112: 3.5460992907801416}, 'hyper': {112: 24.822695035460992}, 'lgbi': {112: 8.921466}, 'hgbi': {112: 7.0495157}, 'ri': {112: 15.970982}, 'sev_hyper': {112: 0.0}}
# {'epi': {112: 226}, 't': {112: 246}, 'reward': {112: 127.38185}, 'normo': {112: 80.08130081300813}, 'hypo': {112: 3.252032520325203}, 'sev_hypo': {112: 2.032520325203252}, 'hyper': {112: 8.130081300813009}, 'lgbi': {112: 7.1312423}, 'hgbi': {112: 7.0700707}, 'ri': {112: 14.201313}, 'sev_hyper': {112: 6.504065040650406}}
# {'epi': {112: 226}, 't': {112: 312}, 'reward': {112: 70.02529}, 'normo': {112: 52.24358974358975}, 'hypo': {112: 5.128205128205129}, 'sev_hypo': {112: 4.807692307692308}, 'hyper': {112: 26.28205128205128}, 'lgbi': {112: 9.194041}, 'hgbi': {112: 15.228436}, 'ri': {112: 24.422478}, 'sev_hyper': {112: 11.538461538461538}}
# {'epi': {112: 226}, 't': {112: 312}, 'reward': {112: 81.16944}, 'normo': {112: 53.84615384615385}, 'hypo': {112: 4.166666666666667}, 'sev_hypo': {112: 0.0}, 'hyper': {112: 37.5}, 'lgbi': {112: 4.550398}, 'hgbi': {112: 13.519772}, 'ri': {112: 18.07017}, 'sev_hyper': {112: 4.487179487179487}}
# {'epi': {112: 226}, 't': {112: 312}, 'reward': {112: 160.47043}, 'normo': {112: 74.03846153846153}, 'hypo': {112: 0.0}, 'sev_hypo': {112: 0.0}, 'hyper': {112: 19.871794871794872}, 'lgbi': {112: 1.3086367}, 'hgbi': {112: 10.711766}, 'ri': {112: 12.020403}, 'sev_hyper': {112: 6.089743589743589}}
