# %%
import os
import sys
import json
import numpy as np
import pandas as pd
from decouple import config
MAIN_PATH = config('MAIN_PATH')
sys.path.insert(1, MAIN_PATH)
from visualiser.core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from visualiser.core import plot_episode, plot_training_action_summary, plot_aux_training, plot_planning_training
from visualiser.core import display_commands, plot_testing_metric, display_commands_v2, plot_testing_average_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
    
# initialise experiment objects
lime, brown, orange, pink, gray, darkorange2 = '#00FF00', '#964B00', '#FFA500', '#FF1493', '#808080', '#EE7600'
darkslateblue, maroon, navyblue = '#483D8B', '#800000', '#000080'
darkgreen =  '#006400'

exp1 = ExperimentVisualise(id='nov17_embc_A1', version=1.1, plot_version=1, test_seeds=5000)
exp2 = ExperimentVisualise(id='nov17_embc_A2', version=1.1, plot_version=1, test_seeds=5000)
exp3 = ExperimentVisualise(id='nov17_embc_A3', version=1.1, plot_version=1, test_seeds=5000)
exp4 = ExperimentVisualise(id='nov17_embc_A4', version=1.1, plot_version=1, test_seeds=5000)
exp5 = ExperimentVisualise(id='nov17_embc_A5', version=1.1, plot_version=1, test_seeds=5000)

# plot the graphs
dis_len = 2* 1000000
command = []
disp_arr = display_commands_v2(command)
exp_vis = {
             '1':{ "id":exp1, "color":darkgreen,"show": disp_arr[1], "label":''}, 
             '2':{ "id":exp2, "color":maroon,"show": disp_arr[2], "label":''},  
            '3':{ "id":exp3, "color":'r',"show": disp_arr[3], "label":''}, 
             '4':{ "id":exp4, "color":'b',"show": disp_arr[4], "label":''},  
              '5':{ "id":exp5, "color":'k',"show": disp_arr[5], "label":''}, 

}
#groups = [['3', '7','10', '11'], ['12', '13','14']]
#plot_testing_average_metric(exp_vis, groups, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)


plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True, label=False)  # normal

plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=70, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='hgbi', goal=5, fill=False)
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='lgbi', goal=1.1, fill=False)
plot_training_logs(exp_vis, dis_len, version=3)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='aBGP_rmse', goal=5, fill=False)
# plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='cBGP_rmse', goal=5, fill=False)
# plot_aux_training(exp_vis, 500, 1)

# plot_planning_training(exp_vis, 500, 1)

# %%
# debugging a given experimentset_args
target_exp = exp18
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=256)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=256)
# Out:
#  Experiment summary...
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 281.68744}, 'normo': {488: 55.76923076923077}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 44.23076923076923}, 'lgbi': {488: 0.0790633}, 'hgbi': {488: 9.872508}, 'ri': {488: 9.951571}, 'sev_hyper': {488: 0.0}, 'aBGP_rmse': {488: 168.73227}, 'cBGP_rmse': {488: 132.25926}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 281.82556}, 'normo': {488: 55.44871794871795}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 41.66666666666666}, 'lgbi': {488: 0.65881675}, 'hgbi': {488: 10.701288}, 'ri': {488: 11.360105}, 'sev_hyper': {488: 2.8846153846153846}, 'aBGP_rmse': {488: 176.17561}, 'cBGP_rmse': {488: 140.36478}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 273.07886}, 'normo': {488: 56.08974358974359}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 34.93589743589744}, 'lgbi': {488: 0.18947028}, 'hgbi': {488: 12.92369}, 'ri': {488: 13.11316}, 'sev_hyper': {488: 8.974358974358974}, 'aBGP_rmse': {488: 164.3575}, 'cBGP_rmse': {488: 129.93195}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 276.7494}, 'normo': {488: 51.6025641025641}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 43.91025641025641}, 'lgbi': {488: 0.29590684}, 'hgbi': {488: 12.383005}, 'ri': {488: 12.678912}, 'sev_hyper': {488: 4.487179487179487}, 'aBGP_rmse': {488: 167.24107}, 'cBGP_rmse': {488: 131.86879}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 258.42798}, 'normo': {488: 30.44871794871795}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 53.20512820512821}, 'lgbi': {488: 0.13724807}, 'hgbi': {488: 18.1521}, 'ri': {488: 18.289349}, 'sev_hyper': {488: 16.346153846153847}, 'aBGP_rmse': {488: 144.87251}, 'cBGP_rmse': {488: 112.52856}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 260.7988}, 'normo': {488: 33.333333333333336}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 53.52564102564103}, 'lgbi': {488: 0.0}, 'hgbi': {488: 16.410637}, 'ri': {488: 16.410637}, 'sev_hyper': {488: 13.14102564102564}, 'aBGP_rmse': {488: 143.51933}, 'cBGP_rmse': {488: 110.63312}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 287.4845}, 'normo': {488: 73.3974358974359}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 18.58974358974359}, 'lgbi': {488: 1.2056378}, 'hgbi': {488: 12.4239645}, 'ri': {488: 13.629602}, 'sev_hyper': {488: 8.012820512820513}, 'aBGP_rmse': {488: 205.59111}, 'cBGP_rmse': {488: 170.16858}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 286.46228}, 'normo': {488: 66.02564102564102}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 33.01282051282051}, 'lgbi': {488: 0.35940054}, 'hgbi': {488: 10.575466}, 'ri': {488: 10.934867}, 'sev_hyper': {488: 0.9615384615384616}, 'aBGP_rmse': {488: 189.91348}, 'cBGP_rmse': {488: 154.02774}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 287.37323}, 'normo': {488: 70.1923076923077}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 22.435897435897434}, 'lgbi': {488: 0.7487884}, 'hgbi': {488: 9.322066}, 'ri': {488: 10.070855}, 'sev_hyper': {488: 7.371794871794871}, 'aBGP_rmse': {488: 190.2717}, 'cBGP_rmse': {488: 154.43726}}
# {'epi': {488: 490}, 't': {488: 312}, 'reward': {488: 268.83554}, 'normo': {488: 41.02564102564103}, 'hypo': {488: 0.0}, 'sev_hypo': {488: 0.0}, 'hyper': {488: 45.833333333333336}, 'lgbi': {488: 0.0}, 'hgbi': {488: 13.834763}, 'ri': {488: 13.834763}, 'sev_hyper': {488: 13.14102564102564}, 'aBGP_rmse': {488: 154.11661}, 'cBGP_rmse': {488: 119.78691}}
