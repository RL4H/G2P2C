# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
lstm32_weightnorm_short= ExperimentVisualise(id='lstm32_weightnorm_short')

# False
exp_vis = {'1':{
                "id":lstm32_weightnorm_short,
                "color":'r',
                "show": True}
           }

# plot the graphs
plot_testing_rewards(exp_vis, 'min_max')  # min_max, normal
plot_training_logs(exp_vis)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# debugging a given experiment
target_exp = short_objective
target_exp.get_summary()
plot_episode(target_exp, tester=0, episode=160)
plot_value_function(target_exp, horizon=100)
plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {185: 186}, 't': {185: 300}, 'reward': {185: 276.04324}, 'normo': {185: 57.0}, 'hypo': {185: 0.0}, 'sev_hypo': {185: 0.0}, 'hyper': {185: 43.0}, 'lgbi': {185: 0.0}, 'hgbi': {185: 7.9855843}, 'ri': {185: 7.9855843}}
# {'epi': {185: 186}, 't': {185: 300}, 'reward': {185: 279.7132}, 'normo': {185: 69.66666666666667}, 'hypo': {185: 0.0}, 'sev_hypo': {185: 0.0}, 'hyper': {185: 30.33333333333333}, 'lgbi': {185: 0.11883799}, 'hgbi': {185: 7.161351}, 'ri': {185: 7.280189}}
# {'epi': {185: 186}, 't': {185: 300}, 'reward': {185: 263.69888}, 'normo': {185: 45.333333333333336}, 'hypo': {185: 0.0}, 'sev_hypo': {185: 0.0}, 'hyper': {185: 54.66666666666666}, 'lgbi': {185: 0.0125072785}, 'hgbi': {185: 12.347062}, 'ri': {185: 12.35957}}
# {'epi': {185: 186}, 't': {185: 300}, 'reward': {185: 286.59174}, 'normo': {185: 77.66666666666667}, 'hypo': {185: 0.0}, 'sev_hypo': {185: 0.0}, 'hyper': {185: 22.33333333333333}, 'lgbi': {185: 0.25135475}, 'hgbi': {185: 5.753178}, 'ri': {185: 6.004533}}
# {'epi': {185: 186}, 't': {185: 300}, 'reward': {185: 281.31506}, 'normo': {185: 72.66666666666667}, 'hypo': {185: 0.0}, 'sev_hypo': {185: 0.0}, 'hyper': {185: 27.33333333333333}, 'lgbi': {185: 0.120270796}, 'hgbi': {185: 6.807901}, 'ri': {185: 6.9281716}}
