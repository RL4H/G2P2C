# %%
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from core import display_commands, plot_testing_metric
from matplotlib import pyplot as plt
import matplotlib.gridspec
# %matplotlib inline 
import pandas as pd
import numpy as np
import json
   
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j24_0_bgpred_1', version=1.1, plot_version=1)
exp2 = ExperimentVisualise(id='j24_0_bgpred_2', version=1.1, plot_version=1)
exp3 = ExperimentVisualise(id='j24_0_bgpred_5', version=1.1, plot_version=1)
exp4 = ExperimentVisualise(id='j24_2_bgpred_1', version=1.1, plot_version=1)
exp5 = ExperimentVisualise(id='j24_2_bgpred_2', version=1.1, plot_version=1)
exp6 = ExperimentVisualise(id='j24_2_bgpred_5', version=1.1, plot_version=1)

command = []
dis_len = 5000000

# plot the graphs
disp_arr = display_commands(command)
exp_vis = {'1':{ "id":exp1, "color":'r',"show": disp_arr[0]}, 
           '2':{ "id":exp2, "color":'g',"show": disp_arr[1]},  
           '3':{ "id":exp3,"color":'b', "show": disp_arr[2]},
           '4':{ "id":exp4, "color":'m', "show": disp_arr[3]},
           '5':{ "id":exp5,"color":'k',"show": disp_arr[4]},
           '6':{ "id":exp6,"color":'c',"show": disp_arr[5]}}
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='reward', goal=312, fill=True)  # normal
#plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='normo', goal=75, fill=False)  # normal
plot_testing_metric(exp_vis, type='min_max', dis_len=dis_len, metric='ri', goal=5, fill=False)
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 300, 20)

# %%
# debugging a given experimentset_args
target_exp = exp1
latest_epi = target_exp.get_summary()
target_epi = latest_epi
plot_value_function(target_exp, horizon=288)
for t in range(0, target_exp.testing_workers):
    plot_episode(target_exp, tester=t, episode=target_epi)
plot_training_action_summary(target_exp, horizon=288)
# Out:
#  Experiment summary...
# {'epi': {46: 94}, 't': {46: 41}, 'reward': {46: 36.200714}, 'normo': {46: 73.17073170731707}, 'hypo': {46: 4.878048780487805}, 'sev_hypo': {46: 7.317073170731708}, 'hyper': {46: 14.634146341463415}, 'lgbi': {46: 17.748173}, 'hgbi': {46: 4.1699944}, 'ri': {46: 21.918167}, 'sev_hyper': {46: 0.0}}
# {'epi': {46: 94}, 't': {46: 34}, 'reward': {46: 30.219276}, 'normo': {46: 85.29411764705883}, 'hypo': {46: 5.882352941176471}, 'sev_hypo': {46: 8.823529411764707}, 'hyper': {46: 0.0}, 'lgbi': {46: 8.322454}, 'hgbi': {46: 2.398629}, 'ri': {46: 10.721084}, 'sev_hyper': {46: 0.0}}
# {'epi': {46: 94}, 't': {46: 38}, 'reward': {46: 31.714783}, 'normo': {46: 76.3157894736842}, 'hypo': {46: 10.526315789473683}, 'sev_hypo': {46: 13.157894736842104}, 'hyper': {46: 0.0}, 'lgbi': {46: 13.433291}, 'hgbi': {46: 1.908595}, 'ri': {46: 15.3418865}, 'sev_hyper': {46: 0.0}}
# {'epi': {46: 94}, 't': {46: 36}, 'reward': {46: 29.781708}, 'normo': {46: 72.22222222222223}, 'hypo': {46: 13.88888888888889}, 'sev_hypo': {46: 13.88888888888889}, 'hyper': {46: 0.0}, 'lgbi': {46: 14.564514}, 'hgbi': {46: 1.8188988}, 'ri': {46: 16.383413}, 'sev_hyper': {46: 0.0}}
# {'epi': {46: 94}, 't': {46: 32}, 'reward': {46: 26.904491}, 'normo': {46: 71.875}, 'hypo': {46: 15.625}, 'sev_hypo': {46: 12.5}, 'hyper': {46: 0.0}, 'lgbi': {46: 14.208364}, 'hgbi': {46: 1.3389065}, 'ri': {46: 15.54727}, 'sev_hyper': {46: 0.0}}
