# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='mygpu_aux_lstm_16_1', version=1.1)
exp2 = ExperimentVisualise(id='mygpu_aux_lstm_16_2', version=1.1)
exp3 = ExperimentVisualise(id='mygpu_aux_lstm_32_1', version=1.1)
exp4 = ExperimentVisualise(id='mygpu_aux_lstm_32_2', version=1.1)

# False
# exp4

exp_vis = {'1':{
                "id":exp1,
                "color":'r',
                "show": True},
           '2':{
                "id":exp2,
                "color":'g',
                "show": True},
           '3':{
                "id":exp3,
                "color":'b',
                "show": True},
           '4':{
                "id":exp4,
                "color":'m',
                "show": True}
           }

# plot the graphs
dis_len = 5000000
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_training_logs(exp_vis, dis_len)
plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp1
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 1020
plot_episode(target_exp, tester=0, episode=target_epi)
plot_episode(target_exp, tester=1, episode=target_epi)
plot_episode(target_exp, tester=2, episode=target_epi)
plot_episode(target_exp, tester=3, episode=target_epi)
plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {510: 1022}, 't': {510: 161}, 'reward': {510: 143.63976}, 'normo': {510: 52.79503105590062}, 'hypo': {510: 10.559006211180124}, 'sev_hypo': {510: 2.484472049689441}, 'hyper': {510: 36.64596273291925}, 'lgbi': {510: 9.649736}, 'hgbi': {510: 10.103538}, 'ri': {510: 19.753273}}
# {'epi': {510: 1022}, 't': {510: 57}, 'reward': {510: 45.113297}, 'normo': {510: 29.82456140350877}, 'hypo': {510: 7.017543859649122}, 'sev_hypo': {510: 3.508771929824561}, 'hyper': {510: 63.1578947368421}, 'lgbi': {510: 11.236682}, 'hgbi': {510: 21.369627}, 'ri': {510: 32.606308}}
# {'epi': {510: 1022}, 't': {510: 118}, 'reward': {510: 99.587524}, 'normo': {510: 57.6271186440678}, 'hypo': {510: 5.084745762711864}, 'sev_hypo': {510: 2.542372881355932}, 'hyper': {510: 37.28813559322034}, 'lgbi': {510: 11.623655}, 'hgbi': {510: 15.545363}, 'ri': {510: 27.169018}}
# {'epi': {510: 1022}, 't': {510: 120}, 'reward': {510: 102.87694}, 'normo': {510: 37.5}, 'hypo': {510: 5.833333333333333}, 'sev_hypo': {510: 3.333333333333333}, 'hyper': {510: 56.66666666666666}, 'lgbi': {510: 14.851182}, 'hgbi': {510: 13.042014}, 'ri': {510: 27.893196}}
# {'epi': {510: 1022}, 't': {510: 63}, 'reward': {510: 48.79827}, 'normo': {510: 30.15873015873016}, 'hypo': {510: 7.936507936507937}, 'sev_hypo': {510: 4.761904761904762}, 'hyper': {510: 61.90476190476191}, 'lgbi': {510: 13.991056}, 'hgbi': {510: 22.98989}, 'ri': {510: 36.980946}}
