# %%
import pandas as pd
from core import ExperimentVisualise, plot_testing_rewards, plot_training_logs, plot_value_function
from core import plot_episode, plot_training_action_summary, plot_aux_training
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import json
# %matplotlib inline    
    
# initialise experiment objects
exp1 = ExperimentVisualise(id='j7_id0', version=1.1)
exp2 = ExperimentVisualise(id='j7_id1', version=1.1)
exp3 = ExperimentVisualise(id='j7_id2', version=1.1)
exp4 = ExperimentVisualise(id='j7_id3', version=1.1)
exp5 = ExperimentVisualise(id='j7_id4', version=1.1)
exp6 = ExperimentVisualise(id='j7_id5', version=1.1)

# False, True
# exp4

exp_vis = {'1':{
                "id":exp1,
                "color":'r',
                "show": True}, 
           '2':{
                "id":exp2,
                "color":'g',
                "show": True},  
           '3':{
                "id":exp3,
                "color":'b',
                "show": True},
           '4':{
                "id":exp4,
                "color":'m',
                "show": False},
           '5':{
                "id":exp5,
                "color":'k',
                "show": False},
           '6':{
                "id":exp6,
                "color":'c',
                "show": True}
           }

# plot the graphs
dis_len = 5000000
plot_testing_rewards(exp_vis, 'min_max', dis_len)  # min_max, normal
plot_training_logs(exp_vis, dis_len, version=2)
plot_aux_training(exp_vis, 2000)

# %%
# debugging a given experimentset_args
target_exp = exp2
target_exp.get_summary()
plot_value_function(target_exp, horizon=100)

target_epi = 892
plot_episode(target_exp, tester=0, episode=target_epi)
plot_episode(target_exp, tester=1, episode=target_epi)
plot_episode(target_exp, tester=2, episode=target_epi)
plot_episode(target_exp, tester=3, episode=target_epi)
plot_episode(target_exp, tester=4, episode=target_epi)

plot_training_action_summary(target_exp, horizon=100)
# Out:
#  Experiment summary...
# {'epi': {445: 892}, 't': {445: 42}, 'reward': {445: 34.689793}, 'normo': {445: 42.85714285714285}, 'hypo': {445: 11.904761904761903}, 'sev_hypo': {445: 7.142857142857143}, 'hyper': {445: 45.23809523809524}, 'lgbi': {445: 14.557949}, 'hgbi': {445: 16.269863}, 'ri': {445: 30.827812}}
# {'epi': {445: 892}, 't': {445: 1}, 'reward': {445: 0.0}, 'normo': {445: 0.0}, 'hypo': {445: 0.0}, 'sev_hypo': {445: 0.0}, 'hyper': {445: 100.0}, 'lgbi': {445: 0.0}, 'hgbi': {445: 99.948044}, 'ri': {445: 99.948044}}
# {'epi': {445: 892}, 't': {445: 66}, 'reward': {445: 56.06571}, 'normo': {445: 56.06060606060606}, 'hypo': {445: 9.090909090909092}, 'sev_hypo': {445: 4.545454545454546}, 'hyper': {445: 34.84848484848485}, 'lgbi': {445: 10.545269}, 'hgbi': {445: 15.165733}, 'ri': {445: 25.711002}}
# {'epi': {445: 892}, 't': {445: 32}, 'reward': {445: 18.062202}, 'normo': {445: 15.625}, 'hypo': {445: 12.5}, 'sev_hypo': {445: 6.25}, 'hyper': {445: 71.875}, 'lgbi': {445: 14.437247}, 'hgbi': {445: 49.192276}, 'ri': {445: 63.629524}}
# {'epi': {445: 892}, 't': {445: 46}, 'reward': {445: 41.222275}, 'normo': {445: 47.82608695652174}, 'hypo': {445: 21.73913043478261}, 'sev_hypo': {445: 6.521739130434782}, 'hyper': {445: 30.43478260869565}, 'lgbi': {445: 15.269843}, 'hgbi': {445: 6.3186493}, 'ri': {445: 21.588493}}
