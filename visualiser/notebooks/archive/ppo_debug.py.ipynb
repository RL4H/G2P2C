# %%
from debug_visualiser import get_debug_info
from matplotlib import pyplot as plt
import matplotlib.gridspec
import numpy as np
import pandas as pd
import json
# %matplotlib inline

seeds = [0]

# episodic rewards...
fig = plt.figure(figsize=(16, 10))
ax = fig.add_subplot(111)

path_ppo = '../results/ppo_exp/reward_summary_0.csv'
data1= pd.read_csv(path_ppo)
ax.plot(data1['reward'], '-b', label="Total Reward - Episode")

path_ppo = '../results/ppo_exp/reward_summary_1.csv'
data1= pd.read_csv(path_ppo)
ax.plot(data1['reward'], '-g', label="Total Reward - Episode")

path_ppo = '../results/ppo_exp/reward_summary_2.csv'
data1= pd.read_csv(path_ppo)
ax.plot(data1['reward'], '-m', label="Total Reward - Episode")

path_ppo = '../results/ppo_exp/reward_summary_3.csv'
data1= pd.read_csv(path_ppo)
ax.plot(data1['reward'], '-c', label="Total Reward - Episode")

path_ppo = '../results/ppo_exp/reward_summary_4.csv'
data1= pd.read_csv(path_ppo)
ax.plot(data1['reward'], '-r', label="Total Reward - Episode")



ax.grid()
ax.set_title('Setting: Agent Control Basal Only with Meal Announcement')
ax.set_xlabel('Episode')
ax.set_ylabel('Reward')
ax.legend(loc="upper right")
plt.show()

# %%
# action history.... 
fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(311)
ax1 = fig.add_subplot(312)
ax2 = fig.add_subplot(313)
path_ppo = '../results/ppo_exp/action_summary_0.csv'
data2= pd.read_csv(path_ppo)
ax.hist(data2['action'], bins = 40)
ax.set_title('Agent Action')
ax1.hist(data2['mean'], bins = 40)
ax1.set_title('Agent Action Mean')
ax2.hist(data2['pump_action'], bins = 40)
ax2.set_title('Final Pump Action')
plt.show()

print(data1.shape[0])
# # reward pi
# fig = plt.figure(figsize=(16, 10))
# ax = fig.add_subplot(111)

# path_ppo = '../results/ppo_debug1/action_summary_0.csv'
# data= pd.read_csv(path_ppo)
# #ax.plot(data['present_reward'], '-g', label="Real time reward")
# # episodic.... 
# fig = plt.figure(figsize=(16, 10))
# ax = fig.add_subplot(111)

# path_ppo = '../results/ppo_debug1/training_summary_0.csv'
# data2= pd.read_csv(path_ppo)
# ax.plot(data2['Average Reward'], '-r', label="Episodic Average Reward")
# ax.plot(data2['RI'], '-g', label="Episodic RI")
# ax.plot(data2['% Normo'], '-b', label="Episodic Normoglycemia")

# ax.grid()
# ax.set_title('Setting: Agent Control Basal Only with Meal Announcement')
# ax.set_xlabel('Episodes')
# ax.set_ylabel('Average Reward')
# ax.legend(loc="upper right")
# # plt.xlim(20, 4000)
# plt.show()
# Out:
# 12
